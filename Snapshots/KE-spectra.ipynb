# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:40151")
client
# Out:
# <Client: 'tcp://127.0.0.1:40151' processes=8 threads=40, memory=157.36 GiB>

# %%
import numpy as np
import xarray as xr
import pandas as pd
import os.path as op
import os
import xrft
import xwavelet
from scipy.interpolate import griddata
from scipy.stats import bootstrap
from xgcm.grid import Grid
from xmitgcm import open_mdsdataset
# from fastjmd95 import rho as densjmd95
import matplotlib.colors as clr
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# ddir = '/tank/chaocean/qjamet/RUNS/ORAR/reruns2/'
ddir = '/tank/groups/climode/qjamet/RUNS/ORAR/reruns2/'
gdir = '/tank/chaocean/grid_chaO/gridMIT_update1/'
# savedir = '/tank/topog/tuchida/Wavelet-spectrum/'
savedir = '/tank/spectre/tuchida/NA-wavelets/'
tdgs = '/tank/tdgs/tuchida/TWA/'
topog = '/tank/topog/tuchida/TWA/'

# %%
grav = 9.81
nensembs = 5
Kh = 20.
K4 = 1e10
Kr = 1e-5
thetaMax = 1e20
rhoConst = 9.998e2
# Cp = 3.994e3
Cp = 3989.244953
# years = np.arange(2008,2013,dtype=int)
ySstart = -15
yNstart = 15
yend = 50
dnf = 2160
nfile = 73

# %%
years = np.arange(1967,1968,dtype=int)
ntimes = np.arange(1419120,1574640+dnf,dnf).reshape(len(years),nfile)
dd = 45  # 
yystart = 0
ntimes[yystart,dd:]
# Out:
# array([1516320, 1518480, 1520640, 1522800, 1524960, 1527120, 1529280,
#        1531440, 1533600, 1535760, 1537920, 1540080, 1542240, 1544400,
#        1546560, 1548720, 1550880, 1553040, 1555200, 1557360, 1559520,
#        1561680, 1563840, 1566000, 1568160, 1570320, 1572480, 1574640])

# %%
xs = [295,318,
      297.5,316,
      300,315
     ]
ys = [37,43,
      30.5,30,
      24,22
     ]
sreg = ['A','B','C','D','E','F']
ntheta = 36
xo = 50e3
# s = xr.DataArray(np.arange(.5,10.5,.5), dims=['scale'], 
#                  coords={'scale':np.arange(.5,10.5,.5)}
#                 )

# %% [markdown]
# # Wavelet

# %% [markdown]
# ## Uniform grid

# %%
reg = 0
dg = 1
ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' % (100)), 
                     grid_dir=gdir,
                     prefix=['snap_diagOcn'], delta_t=2e2,
                     iters=1419120, 
                    ).isel(time=0).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                       YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                       XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                       XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                      ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1})

grid = Grid(ds, periodic=[])

ny, nx = ds.dxC.shape
xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
xT = xT - xT.isel(XC=nx//2)
(xT - xT.isel(YC=-1,XC=0)).plot()
plt.show()

# %%
(yT - yT.isel(YC=0)).plot()
plt.show()

# %%
nmembs = np.arange(100,148)
xchunk = 100
ychunk = 100
dg = 1

yy = yystart

for reg in range(len(xs)):
    dsb = xr.open_zarr(op.join(savedir,'Snaps_EnsMean_0001419123.zarr')
                      ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                            YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                            XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                            XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                           )
    
    ds0 = xr.open_dataset(op.join(savedir,'isoDiags_u_region%02d_1967-01-01.zarr' % reg))
    ds1 = xr.open_dataset(op.join(savedir,'isoDiags_v_region%02d_1967-01-01.zarr' % reg))
    # ds4 = xr.open_dataset(op.join(savedir,'isoDiags-MtE_region%02d_1967-01-01.zarr' % reg))
    ds4 = xr.open_dataset(op.join(savedir,'isoDiags-MtE_reenvisioned_region%02d_1967-01-01.zarr' % reg))
    dks = xr.DataArray(np.abs(np.diff(ds4.scale**-1)).data, dims='scale',
                           coords={'scale':.5*(ds4.scale[1:].data + ds4.scale[:-1].data)}
                          ).interp(scale=ds4.scale, kwargs={"fill_value": "extrapolate"})
    MtE = -(ds4.upupUx + ds4.vpupUy + ds4.wpupUz
            + ds4.upvpVx + ds4.vpvpVy + ds4.wpvpVz
           )
    Ak = (ds0.iso_uA + ds1.iso_vA
          # - (ds4.iso_uA + ds4.iso_vA)
          - MtE
         )
    piw = ((Ak) * dks).cumsum('scale').mean('nmemb')
    # piw = piw.where((piw.scale)**-1>=2e-5).where((piw.scale)**-1<=5e-4).mean('scale',skipna=True).compute()
    piw = piw.where((piw.scale)**-1<=1e-5).mean('scale',skipna=True).compute()
    print(piw)
    
    for nmemb in nmembs:
        if nmemb == 100:
            ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                         % (nmemb)), 
                                 grid_dir=gdir,
                                 prefix=['snap_diagOcn'], delta_t=2e2,
                                 iters=1419123, 
                                ).isel(time=0).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                                   YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                                   XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                                   XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                                  )
        else:
            ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                        % (nmemb)), 
                                                grid_dir=gdir,
                                                prefix=['snap_diagOcn'], delta_t=2e2,
                                                iters=1419123, 
                                               ).isel(time=0).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                                                  YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                                                  XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                                                  XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                                                 )
                           ], dim='nmemb')

            # ds = ds.chunk({'nmemb':6})
    ds.coords['nmemb'] = ('nmemb',nmembs)
    if len(dsb.XG) > len(dsb.XC):
        dsb = dsb.isel(XG=slice(None,-1))
        ds = ds.isel(XG=slice(None,-1))
    
    grid = Grid(ds, periodic=False)
    # print(ds,grid)

    up = grid.interp((ds.UVEL - dsb.UVEL).where(ds.maskW!=0.),
                     'X',boundary='extend'
                    ).isel(Z=[14,18,24],YC=slice(dg,-dg),XC=slice(dg,-dg)).load()
    vp = grid.interp((ds.VVEL - dsb.VVEL).where(ds.maskS!=0.),
                     'Y',boundary='extend'
                    ).isel(Z=[14,18,24],YC=slice(dg,-dg),XC=slice(dg,-dg)).load()
    up.isel(nmemb=0,Z=1).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
    plt.show()

    xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    xT = (xT - xT.isel(XC=0)).values.flatten()
    yT = (yT - yT.isel(YC=0)).values.flatten()
    print(ds.dxC.mean(), ds.dyC.mean())
    dx = ds.dxC.min().values
    dy = ds.dyC.min().values
    N = up.isel(nmemb=0,Z=1).shape
    ss = xr.DataArray(np.linspace(2*np.maximum(dx,dy),10*xo,30)/xo, dims=['scale'], 
                      coords={'scale':np.linspace(2*dx,10*xo,30)/xo}
                     )

    uterp = xr.DataArray(np.ones_like(up.isel(Z=1)), dims=up.isel(Z=1).dims,
                         coords={'nmemb':nmembs,
                                 # 'Z':up.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    vterp = xr.DataArray(np.ones_like(vp.isel(Z=1)), dims=vp.isel(Z=1).dims,
                         coords={'nmemb':nmembs,
                                 # 'Z':vp.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    Aterp = xr.DataArray(np.ones_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), dims=ds.rA.dims,
                         coords={'YC':np.arange(0,N[-2]*dx,dx),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    #         xx, yy = np.meshgrid(np.arange(0,N[-1]*dx,dx), np.arange(0,N[-2]*dx,dx))
    xxx, yyy = np.mgrid[0:N[-1]*dx:dx, 0:N[-2]*dy:dy]
    iz = 1
    for nn in range(len(nmembs)):
#         for iz in range(len(up.Z)):

#             uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (up*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 

#             vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (vp*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 
        uterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
                                           (up*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                           ).isel(nmemb=nn,Z=iz).values.flatten(),
                                           (xxx, yyy) 
                                          ).T 

        vterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
                                           (vp*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                           ).isel(nmemb=nn,Z=iz).values.flatten(),
                                           (xxx, yyy) 
                                          ).T 
            
    Aterp = griddata((xT, yT), (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
                     (xxx, yyy) 
                    ).T
    uterp = uterp / Aterp
    vterp = vterp / Aterp
    uterp.isel(nmemb=0).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
    plt.show()
    #             print(nn)


    iso_psU = xwavelet.wvlt_power_spectrum(
                    uterp.chunk({'nmemb':1}), ss, dim=["YC", "XC"], xo=xo, ntheta=ntheta
            )
    iso_psV = xwavelet.wvlt_power_spectrum(
                    vterp.chunk({'nmemb':1}), ss, dim=["YC", "XC"], xo=xo, ntheta=ntheta
            )

    fig, ax = plt.subplots()
    ax2 = ax.twiny()
    ax.plot((iso_psU.scale)**-1*1e3, 
            .5*(iso_psU + iso_psV).mean('nmemb').where(piw.isel(Z=iz)<0.).sum('angle',skipna=True)*np.diff(iso_psU.angle)[0]*2,
            'c', lw=2, label=r"$\overline{\tilde{\epsilon}_K}^{>100km}<0$")
    ax.plot((iso_psU.scale)**-1*1e3, 
            .5*(iso_psU + iso_psV).mean('nmemb').where(piw.isel(Z=iz)>0.).sum('angle',skipna=True)*np.diff(iso_psU.angle)[0]*2,
            'r', lw=2, label=r"$\overline{\tilde{\epsilon}_K}^{>100km}>0$")
    ax.plot((iso_psU.scale)**-1*1e3, 
            .5*(iso_psU + iso_psV).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2,
            'k', lw=2, label=r"Isotropic")
    # ax.plot((iso_psU.scale)**-1*1e3, .5*(iso_psU + iso_psV).isel(angle=0,Z=1).mean(['nmemb']),
    #         'r:', lw=2)
    # ax.plot((iso_psU.scale)**-1*1e3, .5*(iso_psU + iso_psV).isel(angle=ntheta//2//2-1,Z=1).mean(['nmemb']),
    #         'c:', lw=2)
    # ax.plot((iso_psU.scale)**-1*1e3, .5*(iso_psU + iso_psV).isel(Z=1).mean(['nmemb','angle']),
    #         'k:', lw=2, label=r"(Z=-1137)")
    if reg == 0:
        ax.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[-1])**-1)**-3
                *1.*(iso_psU + iso_psV).isel(scale=-1).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*1e-1, 
                ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
        ax.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[0])**-1)**-(13/3)
                *.5*(iso_psU + iso_psV).isel(scale=0).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*4e0, 
                ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
        ax2.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[-1])**-1)**-3
                 *.5*(iso_psU + iso_psV).isel(scale=-1).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*1e-1, 
                 ls='--', c='grey', alpha=0)
    elif reg == 1:
        ax.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[-1])**-1)**-3
                *1.*(iso_psU + iso_psV).isel(scale=-1).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*4e-1, 
                ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
        ax.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[0])**-1)**-(13/3)
                *.5*(iso_psU + iso_psV).isel(scale=0).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*1e0, 
                ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
        ax2.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[-1])**-1)**-3
                 *.5*(iso_psU + iso_psV).isel(scale=-1).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*1e-1, 
                 ls='--', c='grey', alpha=0)
    elif reg > 1 and reg < 4:
        ax.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[0])**-1)**-3
                *.5*(iso_psU + iso_psV).isel(scale=0).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*5e2, 
                ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
        ax.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[0])**-1)**-(13/3)
                *.5*(iso_psU + iso_psV).isel(scale=0).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*5e1, 
                ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
        ax2.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[-1])**-1)**-3
                 *.5*(iso_psU + iso_psV).isel(scale=-1).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*1e-1, 
                 ls='--', c='grey', alpha=0)
    elif reg == 4:
        ax.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[0])**-1)**-3
                *.5*(iso_psU + iso_psV).isel(scale=0).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*1e3,
                ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
        ax.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[0])**-1)**-(13/3)
                *.5*(iso_psU + iso_psV).isel(scale=0).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*5e2, 
                ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
        ax2.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[-1])**-1)**-3
                 *.5*(iso_psU + iso_psV).isel(scale=-1).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*1e-1, 
                 ls='--', c='grey', alpha=0)
    else:
        ax.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[0])**-1)**-3
                *.5*(iso_psU + iso_psV).isel(scale=0).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*1e3,
                ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
        ax.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[0])**-1)**-(13/3)
                *.5*(iso_psU + iso_psV).isel(scale=0).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*5e1, 
                ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
        ax2.plot((iso_psU.scale)**-1*1e3, ((iso_psU.scale/iso_psU.scale[-1])**-1)**-3
                 *.5*(iso_psU + iso_psV).isel(scale=-1).mean('nmemb').sum('angle')*np.diff(iso_psU.angle)[0]*2*1e-1, 
                 ls='--', c='grey', alpha=0)
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax2.set_xscale('log')
    ax2.set_yscale('log')
    ax.set_xlim([1e-3,1e-1])
    ax2.set_xlim([1e-3,1e-1])
    ax2.set_xticks([1e-3,1e-2,1e-1])
    ax2.set_xticklabels([1e3,1e2,1e1])
    ax.set_xlabel(r"[cpkm]", fontsize=13)
    ax2.set_xlabel(r"[km]", fontsize=13)
    ax.set_ylabel(r"[(m$^2$ s$^{-2}$) / cpm]", fontsize=13)
    if reg == 0:
        ax.legend(loc='lower left', fontsize=12)
    plt.savefig(op.join('/tank/topog/tuchida/Wavelet-spectrum/Figs/interpSnapKE-spec_Region%02d_Z452.pdf' % reg))
    plt.show()
# Out:
# /tank/users/tuchida/miniconda3/envs/xgcm/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/xgcm/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# <xarray.DataArray (Z: 3, angle: 18)>
# array([[-1.35558669e-09, -7.44449759e-09,  4.97001190e-09,
#          2.07592929e-08,  2.60853410e-08,  2.97843661e-08,
#          1.62543154e-08,  3.69073451e-09,  1.36418317e-09,
#          9.96845285e-09,  5.40915342e-09, -1.02775675e-08,
#         -1.54183199e-08, -9.73288077e-09,  7.02092186e-09,
#          1.72339294e-08,  1.79962865e-08,  8.41678449e-09],
#        [ 6.36584354e-10, -1.33614825e-09,  1.10995068e-09,
#          5.32694830e-09,  8.06005204e-09,  9.61597587e-09,
#          4.67498301e-09,  5.87486613e-10, -9.06255496e-11,
#          1.06264910e-09, -4.63184522e-10, -3.55783755e-09,
#         -5.23234083e-09, -3.96769752e-09,  9.11932515e-10,
#          4.19827955e-09,  5.57771053e-09,  3.91304508e-09],
#        [-2.86432121e-11, -4.61500254e-11,  4.02939530e-11,
#          9.70511730e-11,  4.63188713e-10,  6.12725968e-10,
#          7.05985660e-11, -3.25393924e-10, -2.81714155e-10,
#         -3.63248979e-11, -3.39673704e-11, -1.72545482e-10,
#         -2.21772596e-10, -9.29493416e-11, -9.67892170e-12,
#          1.01024360e-10,  2.31541379e-10,  1.71073027e-10]])
# Coordinates:
#   * Z        (Z) float32 -227.6 -452.4 -1.137e+03
#   * angle    (angle) float64 0.0 0.1745 0.3491 0.5236 ... 2.618 2.793 2.967
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1419123
#     time     timedelta64[ns] 3285 days 00:10:00 <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1419123
#     time     timedelta64[ns] 3285 days 00:10:00
# /tank/users/tuchida/miniconda3/envs/xgcm/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/xgcm/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# <xarray.DataArray (Z: 3, angle: 18)>
# array([[-1.95391412e-09, -2.39032286e-09, -1.08428895e-09,
#         -2.70528705e-09, -4.27151902e-09, -2.35465769e-09,
#          2.35861501e-09,  3.37806761e-09,  3.47356682e-09,
#          1.19228945e-10, -4.27806978e-09, -1.00305012e-08,
#         -1.36787751e-08, -5.19542680e-09,  4.86923089e-09,
#          8.33379735e-09,  4.56391254e-09,  1.45486126e-09],
#        [-6.33965940e-10, -1.22265296e-09, -7.06713156e-10,
#         -6.90492538e-10, -1.61237112e-09, -9.75060504e-10,
#          4.42626577e-10,  7.92052465e-10,  6.87845523e-10,
#         -2.69232077e-10, -1.29608509e-09, -2.68127628e-09,
#         -4.13343585e-09, -1.78064199e-09,  1.69209573e-09,
#          3.47187261e-09,  2.83235096e-09,  1.07645317e-09],
#        [-8.50636093e-11, -5.73698770e-10, -7.35818371e-10,
#         -6.78477336e-10, -9.27938065e-10, -4.42923301e-10,
#          7.07991225e-11,  1.91684862e-10, -6.57398681e-12,
#         -1.77710722e-10, -3.22386714e-10, -4.82115197e-10,
#         -6.83846957e-10, -9.20263786e-11,  7.40825158e-10,
#          1.19673834e-09,  9.39689263e-10,  4.39662720e-10]])
# Coordinates:
#   * Z        (Z) float32 -227.6 -452.4 -1.137e+03
#   * angle    (angle) float64 0.0 0.1745 0.3491 0.5236 ... 2.618 2.793 2.967
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1419123
#     time     timedelta64[ns] 3285 days 00:10:00 <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1419123
#     time     timedelta64[ns] 3285 days 00:10:00
# /tank/users/tuchida/miniconda3/envs/xgcm/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/xgcm/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# <xarray.DataArray (Z: 3, angle: 18)>
# array([[-4.45056602e-10, -1.94374554e-09, -2.78177052e-09,
#         -3.51727643e-09, -4.27079139e-09, -4.04778964e-09,
#         -2.82233331e-09, -1.01657920e-09, -2.99129700e-10,
#          3.40780368e-11,  5.34341535e-10,  1.43266922e-09,
#          2.64989644e-09,  3.52113797e-09,  3.67163004e-09,
#          3.14087553e-09,  2.05415269e-09,  1.14498881e-09],
#        [-2.29428174e-10, -8.66051447e-10, -1.08846278e-09,
#         -1.35611856e-09, -1.72801504e-09, -1.48460075e-09,
#         -9.90354417e-10, -4.64022613e-10, -2.05409181e-10,
#         -1.68066899e-11,  1.43980486e-10,  5.26424445e-10,
#          9.67841783e-10,  1.29575962e-09,  1.42499074e-09,
#          1.23735531e-09,  7.56861133e-10,  3.70202489e-10],
#        [-3.46436353e-13, -5.49099121e-11, -8.29795864e-11,
#         -1.03865236e-10, -7.56479586e-11, -3.19943447e-11,
#         -1.52040359e-12,  9.33479957e-12,  7.69680079e-12,
#          4.24515052e-13, -1.69858517e-11, -1.00007082e-11,
#          4.11891788e-11,  5.43187236e-11,  7.91799717e-11,
#          8.23760071e-11,  7.99604385e-11,  5.71059041e-11]])
# Coordinates:
#   * Z        (Z) float32 -227.6 -452.4 -1.137e+03
#   * angle    (angle) float64 0.0 0.1745 0.3491 0.5236 ... 2.618 2.793 2.967
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1419123
#     time     timedelta64[ns] 3285 days 00:10:00 <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1419123
#     time     timedelta64[ns] 3285 days 00:10:00
# /tank/users/tuchida/miniconda3/envs/xgcm/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/xgcm/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# <xarray.DataArray (Z: 3, angle: 18)>
# array([[-2.23681752e-11, -1.34476011e-10, -2.23440798e-10,
#         -3.27586820e-10, -2.33932606e-10, -1.24441856e-10,
#         -5.79835258e-11, -9.30369126e-11, -4.48300393e-11,
#         -8.06928550e-11, -1.31590646e-10, -1.27740389e-10,
#         -1.47813699e-10, -1.37255096e-10,  2.09711686e-11,
#          3.29887522e-11,  1.31755133e-10,  8.99065799e-11],
#        [-9.63491406e-13, -4.97695699e-11, -8.17498541e-11,
#         -1.46852929e-10, -1.37439450e-10, -6.87497609e-11,
#         -3.52178394e-11, -3.87099255e-11, -3.56711036e-11,
#         -5.40965209e-11, -4.50046096e-11,  1.29627492e-11,
#          9.62881563e-13,  1.89903952e-12,  4.40351875e-11,
#          7.51331702e-11,  6.81520796e-11,  4.26244624e-11],
#        [-3.97944855e-12, -7.46088285e-12, -1.31648520e-11,
#         -2.02804847e-11, -3.01420797e-11, -1.85462565e-11,
#         -5.58585718e-12, -6.10847399e-12, -2.57331969e-12,
#         -5.26474461e-12, -2.85997063e-12, -3.29993001e-12,
#         -1.32070191e-11, -1.99565260e-12, -7.44589676e-12,
#         -1.19774363e-11, -1.19938490e-12, -2.72742223e-12]])
# Coordinates:
#   * Z        (Z) float32 -227.6 -452.4 -1.137e+03
#   * angle    (angle) float64 0.0 0.1745 0.3491 0.5236 ... 2.618 2.793 2.967
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1419123
#     time     timedelta64[ns] 3285 days 00:10:00 <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1419123
#     time     timedelta64[ns] 3285 days 00:10:00
# /tank/users/tuchida/miniconda3/envs/xgcm/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/xgcm/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# <xarray.DataArray (Z: 3, angle: 18)>
# array([[ 2.35321943e-11, -3.47629326e-11, -4.68560967e-12,
#          4.47850509e-11, -1.57969280e-11,  5.86592284e-11,
#          1.99477564e-10,  2.59752441e-10,  1.16282669e-10,
#         -3.31888311e-11, -1.56513618e-10, -2.36402552e-10,
#         -1.25347702e-10,  6.55042979e-11,  9.18475214e-11,
#          9.18993025e-11,  9.54720153e-11,  3.74797041e-11],
#        [-4.86690998e-12, -1.91966196e-11,  9.83929684e-12,
#          1.16694951e-11, -4.56225270e-11, -2.68535753e-11,
#          2.61122860e-11,  1.10681681e-11, -1.00016669e-11,
#         -1.76274982e-11, -3.80687158e-11, -1.03082523e-11,
#          4.77802016e-12,  1.44951996e-11,  3.50710965e-11,
#          8.24912493e-12,  3.49224246e-11, -5.73611043e-12],
#        [ 8.37983104e-12, -1.06645629e-11,  9.91972807e-14,
#          2.60014558e-12, -1.61137515e-11,  2.05797035e-11,
#          3.61586611e-11,  4.37527750e-11,  3.90306479e-11,
#          1.91884959e-11, -5.42881474e-12, -2.92071470e-11,
#         -3.45277615e-11, -2.29152392e-11,  3.93467587e-12,
#          1.64827070e-11,  6.76731743e-12, -4.02692889e-12]])
# Coordinates:
#   * Z        (Z) float32 -227.6 -452.4 -1.137e+03
#   * angle    (angle) float64 0.0 0.1745 0.3491 0.5236 ... 2.618 2.793 2.967
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1419123
#     time     timedelta64[ns] 3285 days 00:10:00 <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1419123
#     time     timedelta64[ns] 3285 days 00:10:00
# /tank/users/tuchida/miniconda3/envs/xgcm/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/xgcm/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# <xarray.DataArray (Z: 3, angle: 18)>
# array([[-7.48900954e-12, -5.01051255e-11, -4.72801442e-11,
#         -2.98322794e-11, -3.28174449e-11,  3.66846512e-12,
#          2.31993165e-11,  2.65546755e-11,  1.09773991e-11,
#         -7.16543057e-12, -2.16374532e-11, -1.98504244e-11,
#         -1.16160993e-11,  3.37504590e-11,  8.07112145e-11,
#          6.96715929e-11,  4.90696677e-11,  6.42805630e-11],
#        [-2.93244572e-12, -3.02301437e-13,  1.24121170e-11,
#          2.15906219e-11,  1.33263882e-11,  5.50995572e-11,
#          6.25000172e-11,  5.55324322e-11,  1.78190757e-11,
#         -8.02532033e-12, -1.40190290e-11, -2.85046492e-11,
#         -4.24598224e-11, -3.40106284e-11, -2.37286357e-11,
#         -3.46962113e-11, -1.05466248e-11,  2.60442199e-12],
#        [ 3.01171869e-12,  8.61795014e-13,  8.33010316e-12,
#          2.37792412e-11,  1.45815140e-11,  2.77674646e-11,
#          3.85344026e-11,  3.18752265e-11,  2.33407521e-11,
#          1.80371317e-12, -4.59258398e-12, -9.54319144e-12,
#         -1.95472607e-11, -1.09152789e-11, -1.10527577e-11,
#         -1.41488817e-11, -8.84761104e-12, -2.12259174e-12]])
# Coordinates:
#   * Z        (Z) float32 -227.6 -452.4 -1.137e+03
#   * angle    (angle) float64 0.0 0.1745 0.3491 0.5236 ... 2.618 2.793 2.967
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1419123
#     time     timedelta64[ns] 3285 days 00:10:00 <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1419123
#     time     timedelta64[ns] 3285 days 00:10:00

# %% [markdown]
# ## TKE

# %%
# reg = 3
dg = 1
nmembs = np.arange(100,148)

iiter = 1419120
# iiter = 1421280
# iiter = 1423440

for reg in range(4,len(xs)):
    
    for nmemb in nmembs:
        if nmemb == 100:
            ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                         % (nmemb)), 
                                 grid_dir=gdir,
                                 prefix=['snap_diagOcn'], delta_t=2e2,
                                 iters=iiter, 
                                ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                      XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                     ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
        else:
            ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                        % (nmemb)), 
                                                grid_dir=gdir,
                                                prefix=['snap_diagOcn'], delta_t=2e2,
                                                iters=iiter, 
                                               ).sel(YC=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     YG=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     XC=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12),
                                                     XG=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12)
                                                    ).chunk({'Z':1,'Zl':1,'Zu':1,
                                                             'Zp1':1}).isel(time=0)
                           ], dim='nmemb')

            # ds = ds.chunk({'nmemb':6})
    ds.coords['nmemb'] = ('nmemb',nmembs)
    # if reg == 0:
    #     print(ds)
    if len(ds.XG) > len(ds.XC):
        ds = ds.isel(XG=slice(None,-1))
        
    grid = Grid(ds, periodic=[])
    
    xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    ny, nx = xT.shape
    xT = xT - xT.isel(XC=nx//2)
    # (xT - xT.isel(YC=-1,XC=0)).plot()
    # plt.show()
    xT = (xT - xT.isel(YC=-1,XC=0)).values.flatten()
    yT = (yT - yT.isel(YC=0)).values.flatten()

    u = grid.interp(ds.UVEL,'X',boundary='extend'
                    ).where(ds.maskC!=0.).isel(Z=[14,18,24],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='XC'
                                                 ).interpolate_na(dim='YC'
                                                                 ).fillna(0.)
    v = grid.interp(ds.VVEL,'Y',boundary='extend'
                    ).where(ds.maskC!=0.).isel(Z=[14,18,24],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='YC'
                                                 ).interpolate_na(dim='XC'
                                                                 ).fillna(0.)
    iZ = 1
    u.isel(nmemb=0,Z=iZ).plot(vmax=1, vmin=-1, cmap='RdBu_r')
    plt.show()
    
    print(ds.dxC.mean(), ds.dyC.mean())
    dx = ds.dxC.min().values
    dy = ds.dyC.min().values
    N = u.isel(nmemb=0,Z=iZ).shape


    uterp = xr.DataArray(np.zeros_like(u.isel(Z=iZ)), dims=u.isel(Z=iZ).dims,
                         coords={'nmemb':nmembs,
                                 # 'Z':up.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    vterp = xr.DataArray(np.zeros_like(v.isel(Z=iZ)), dims=v.isel(Z=iZ).dims,
                         coords={'nmemb':nmembs,
                                 # 'Z':vp.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    Aterp = xr.DataArray(np.zeros_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), 
                         dims=ds.rA.dims,
                         coords={'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    #         xx, yy = np.meshgrid(np.arange(0,N[-1]*dx,dx), np.arange(0,N[-2]*dx,dx))
    xxx, yyy = np.mgrid[0:nx*dx:dx, 0:ny*dy:dy]
    for nn in range(len(nmembs)):
#         for iz in range(len(up.Z)):

#             uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (up*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 

#             vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (vp*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T
        uterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
                                           (u*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                           ).isel(nmemb=nn,Z=iZ).values.flatten(),
                                           (xxx, yyy) 
                                          ).T 

        vterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
                                           (v*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                           ).isel(nmemb=nn,Z=iZ).values.flatten(),
                                           (xxx, yyy) 
                                          ).T

    Aterp = griddata((xT, yT), 
                     (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
                     (xxx, yyy) 
                    ).T
    uterp = uterp / Aterp
    vterp = vterp / Aterp
    uterp.isel(nmemb=0).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
    plt.show()
    
    iso_psUf = xrft.isotropic_power_spectrum(
                    uterp.interpolate_na(dim='XC').interpolate_na(dim='YC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
    iso_psVf = xrft.isotropic_power_spectrum(
                    vterp.interpolate_na(dim='YC').interpolate_na(dim='XC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
    ss = xr.DataArray(np.linspace(iso_psUf.freq_r[-1].data**-1,
                                  iso_psUf.freq_r[0].data**-1,40)/xo,
                      dims=['scale'], 
                      coords={'scale':np.linspace(iso_psUf.freq_r[-1].data**-1,
                                                  iso_psUf.freq_r[0].data**-1,40)/xo}
    )
    ssf = xr.DataArray(iso_psUf.freq_r.data**-1/xo, dims=['scale'], 
                       coords={'scale':iso_psUf.freq_r.data**-1/xo}
                      )
    ssh = xr.concat([ss.where(ss>50e3/xo).dropna('scale')[::-1],
                     ssf.where(ssf<50e3/xo).dropna('scale')
                    ], 'scale')
#     print(len(ssf),len(ssh))
    iso_psUw = xwavelet.wvlt_power_spectrum(
                    uterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
                    xo=xo, ntheta=ntheta
    ) 
    iso_psVw = xwavelet.wvlt_power_spectrum(
                    vterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
                    xo=xo, ntheta=ntheta
    )
    
    dsave = iso_psUw.to_dataset(name='U')
    dsave['V'] = iso_psVw
    dsave.to_zarr(op.join(savedir,'Z0452/Points/%s/%010d/isoDiags_TKE.zarr' 
                          % (sreg[reg],iiter)), mode='w')
    
#     dsw = xr.open_zarr(op.join(savedir,'Z0000/Points/%s/%010d/isoDiags_TKE.zarr' 
#                                % (sreg[reg],iiter))
#                       )
#     iso_psUw = dsw.U
#     iso_psVw = dsw.V
#     _, a, b = xrft.fit_loglog((dsw.scale.sel(scale=slice(250e3,40e3))).values**-1,
#                           (iso_psUw + iso_psVw
#                           ).mean(['nmemb','angle']).sel(scale=slice(250e3,40e3)).values
#          )
#     print(a,b)
            
#     w3 = (.5*(iso_psUw + iso_psVw).mean(['nmemb','angle'])
#           / ((iso_psUw.scale)**-1)**-3)
#     # w133 = (.5*(iso_psUw + iso_psVw).mean(['nmemb','angle'])
#     #         / ((iso_psUw.scale)**-1)**(-13/3))
#     w413 = (.5*(iso_psUw + iso_psVw).mean(['nmemb','angle'])
#             / ((iso_psUw.scale)**-1)**(a))
#     f3 = (.5*(iso_psUf + iso_psVf).mean(['nmemb'])
#           / (iso_psUf.freq_r)**-3)
#     # f133 = (.5*(iso_psUf + iso_psVf).mean(['nmemb'])
#     #         / (iso_psUf.freq_r)**(-13/3))
#     f413 = (.5*(iso_psUf + iso_psVf).mean(['nmemb'])
#             / (iso_psUf.freq_r)**(a))

    
#     datas = (.5*(iso_psUw + iso_psVw).sum('angle')
#              * np.diff(iso_psVw.angle)[0]*2,
#             )  # samples must be in a sequence
#     rng = np.random.default_rng()
#     Wres = bootstrap(datas, np.mean, confidence_level=0.95,
#                      random_state=rng)
#     datas = (.5*(iso_psUf + iso_psVf) * 2*np.pi,)  # samples must be in a sequence
#     rng = np.random.default_rng()
#     Fres = bootstrap(datas, np.mean, confidence_level=0.95,
#                      random_state=rng)
    
#     fig, (ax1,ax3) = plt.subplots(figsize=(10,4), nrows=1, ncols=2)
#     fig.set_tight_layout(True)
#     ax2 = ax1.twiny()
#     ax4 = ax3.twiny()
    
#     ax1.fill_between((iso_psUw.scale)**-1*1e3, 
#                      Wres.confidence_interval.low, Wres.confidence_interval.high, 
#                      alpha=.4, color='k')
#     ax1.fill_between((iso_psUf.freq_r)*1e3, 
#                      Fres.confidence_interval.low, Fres.confidence_interval.high, 
#                      alpha=.36, color='r')
    
#     ax1.plot((iso_psUw.scale)**-1*1e3, 
#              .5*(iso_psUw + iso_psVw).mean(['nmemb']).sum('angle')
#              * np.diff(iso_psVw.angle)[0]*2,
#              'k', lw=2, label=r"Wavelet")
#     ax1.plot((iso_psUf.freq_r)*1e3, 
#              .5*(iso_psUf + iso_psVf).mean(['nmemb']) * 2*np.pi,
#              'r', lw=2, label=r"Fourier")
#     ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*6e0, 
#              ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
#     # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*2e0, 
#     #          ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
#     ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**a*4e0, 
#              ls=':', c='grey', alpha=.8, label=r"$k^{-4.16}$")
            
#     ax3.plot((iso_psUw.scale)**-1*1e3, w3/w3.mean(),
#              'k--', label=r"$\alpha=3$")
#     # ax3.plot((iso_psUw.scale)**-1*1e3, w133/w133.mean(),
#     #          'k-.', label=r"$\alpha=13/3$")
#     ax3.plot((iso_psUw.scale)**-1*1e3, w413/w413.mean(),
#              'k:', lw=2, label=r"$\alpha=4.13$")
#     ax3.plot((iso_psUf.freq_r)*1e3, f3/f3.mean(),
#              'r--', label=r"")
#     # ax3.plot((iso_psUf.freq_r)*1e3, f133/f133.mean(),
#     #          'r-.', label=r"")
#     ax3.plot((iso_psUf.freq_r)*1e3, f413/f413.mean(),
#              'r:', lw=2, label=r"")

#     ax1.set_xscale('log')
#     ax1.set_yscale('log')
#     ax3.set_xscale('log')
#     ax3.set_yscale('log')
#     ax2.set_xscale('log')
#     ax2.set_yscale('log')
#     ax4.set_xscale('log')
#     ax4.set_yscale('log')
#     ax1.set_ylim([1e-3,4e4])
#     ax1.set_xlim([1e-3,1e-1])
#     ax2.set_xlim([1e-3,1e-1])
#     ax3.set_xlim([1e-3,1e-1])
#     ax4.set_xlim([1e-3,1e-1])
#     ax2.set_xticks([1e-3,1e-2,1e-1])
#     ax2.set_xticklabels([1e3,1e2,1e1])
#     ax4.set_xticks([1e-3,1e-2,1e-1])
#     ax4.set_xticklabels([1e3,1e2,1e1])
#     ax1.set_xlabel(r"[cpkm]", fontsize=13)
#     ax2.set_xlabel(r"[km]", fontsize=13)
#     ax1.set_ylabel(r"$E_K$ [(m$^2$ s$^{-2}$) / cpm]", fontsize=13)
#     ax3.set_xlabel(r"[cpkm]", fontsize=13)
#     ax4.set_xlabel(r"[km]", fontsize=13)
#     ax3.set_ylabel(r"$E_K~/~k^{-\alpha}$", fontsize=13)
#     if reg == 0:
#         ax1.legend(loc='lower left', fontsize=12)
#         ax3.legend(loc='lower left', fontsize=12)
#     ax3.grid(True)
#     plt.savefig(op.join(savedir,
#         'Figs/WvsF-TKE-spec_Region%02d_integrated_Z452_%010d.pdf' 
#                         % (reg,iiter))
#                )
#     plt.show()
# Out:
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 dask.array<chunksize=(), meta=np.ndarray>
#     time     timedelta64[ns] 3285 days <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 dask.array<chunksize=(), meta=np.ndarray>
#     time     timedelta64[ns] 3285 days
# /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/xwavelet/wavelet.py:296: FutureWarning: This function has been renamed and will disappear in the future. Please use `power_spectrum` instead.
#   warnings.warn(msg, FutureWarning)
# /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/xwavelet/wavelet.py:296: FutureWarning: This function has been renamed and will disappear in the future. Please use `power_spectrum` instead.
#   warnings.warn(msg, FutureWarning)
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 dask.array<chunksize=(), meta=np.ndarray>
#     time     timedelta64[ns] 3285 days <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 dask.array<chunksize=(), meta=np.ndarray>
#     time     timedelta64[ns] 3285 days
# /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/xwavelet/wavelet.py:296: FutureWarning: This function has been renamed and will disappear in the future. Please use `power_spectrum` instead.
#   warnings.warn(msg, FutureWarning)
# /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/xwavelet/wavelet.py:296: FutureWarning: This function has been renamed and will disappear in the future. Please use `power_spectrum` instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## EKE

# %%
# reg = 3
dg = 1
nmembs = np.arange(100,148)

iiter = 1419120
# iiter = 1421280
# iiter = 1423440

for reg in range(len(xs)-5):
    
    dsb = open_mdsdataset(op.join(ddir,'ensm/run1967/ocn'), 
                          grid_dir=gdir,
                          prefix=['snap_diagOcn'], delta_t=2e2,
                          iters=iiter, 
                         ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                               XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                              ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
    
    for nmemb in nmembs:
        if nmemb == 100:
            ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                         % (nmemb)), 
                                 grid_dir=gdir,
                                 prefix=['snap_diagOcn'], delta_t=2e2,
                                 iters=iiter, 
                                ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                      XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                     ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
        else:
            ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                        % (nmemb)), 
                                                grid_dir=gdir,
                                                prefix=['snap_diagOcn'], delta_t=2e2,
                                                iters=iiter, 
                                               ).sel(YC=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     YG=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     XC=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12),
                                                     XG=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12)
                                                    ).chunk({'Z':1,'Zl':1,'Zu':1,
                                                             'Zp1':1}).isel(time=0)
                           ], dim='nmemb')

            # ds = ds.chunk({'nmemb':6})
    ds.coords['nmemb'] = ('nmemb',nmembs)
    # if reg == 0:
    #     print(ds)
    if len(dsb.XG) > len(dsb.XC):
        dsb = dsb.isel(XG=slice(None,-1))
        ds = ds.isel(XG=slice(None,-1))
        
    grid = Grid(ds, periodic=[])
    
    xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    ny, nx = xT.shape
    xT = xT - xT.isel(XC=nx//2)
    # (xT - xT.isel(YC=-1,XC=0)).plot()
    # plt.show()
    xT = (xT - xT.isel(YC=-1,XC=0)).values.flatten()
    yT = (yT - yT.isel(YC=0)).values.flatten()

    up = grid.interp((ds.UVEL - dsb.UVEL).where(ds.maskW!=0.),
                     'X',boundary='extend'
                    ).isel(Z=[0,18,24],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='XC'
                                                 ).interpolate_na(dim='YC'
                                                                 ).fillna(0.)
    vp = grid.interp((ds.VVEL - dsb.VVEL).where(ds.maskS!=0.),
                     'Y',boundary='extend'
                    ).isel(Z=[0,18,24],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='YC'
                                                 ).interpolate_na(dim='XC'
                                                                 ).fillna(0.)
    
    iZ = 1
    up.isel(nmemb=0,Z=iZ).plot(vmax=1, vmin=-1, cmap='RdBu_r')
    plt.show()
    
    print(ds.dxC.mean(), ds.dyC.mean())
    dx = ds.dxC.min().values
    dy = ds.dyC.min().values
    N = up.isel(nmemb=0,Z=iZ).shape

    
    uterp = xr.DataArray(np.zeros_like(up.isel(Z=iZ)), dims=up.dims,
                         coords={'nmemb':nmembs,
                                 # 'Z':up.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    vterp = xr.DataArray(np.zeros_like(vp.isel(Z=iZ)), dims=vp.isel(Z=iZ).dims,
                         coords={'nmemb':nmembs,
                                 # 'Z':vp.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    Aterp = xr.DataArray(np.zeros_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), 
                         dims=ds.rA.dims,
                         coords={'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    #         xx, yy = np.meshgrid(np.arange(0,N[-1]*dx,dx), np.arange(0,N[-2]*dx,dx))
    xxx, yyy = np.mgrid[0:nx*dx:dx, 0:ny*dy:dy]
    for nn in range(len(nmembs)):
#         for iz in range(len(up.Z)):

#             uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (up*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 

#             vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (vp*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T
        uterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
                                           (up*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                           ).isel(nmemb=nn,Z=iZ).values.flatten(),
                                           (xxx, yyy) 
                                          ).T 

        vterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
                                           (vp*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                           ).isel(nmemb=nn,Z=iZ).values.flatten(),
                                           (xxx, yyy) 
                                          ).T

    Aterp = griddata((xT, yT), 
                     (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
                     (xxx, yyy) 
                    ).T
    uterp = uterp / Aterp
    vterp = vterp / Aterp
    uterp.isel(nmemb=0).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
    plt.show()
    
    iso_psUf = xrft.isotropic_power_spectrum(
                    uterp.interpolate_na(dim='XC').interpolate_na(dim='YC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
    iso_psVf = xrft.isotropic_power_spectrum(
                    vterp.interpolate_na(dim='YC').interpolate_na(dim='XC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
    # ss = xr.DataArray(np.linspace(iso_psUf.freq_r[-1].data**-1,
    #                               iso_psUf.freq_r[0].data**-1,40)/xo,
#                       dims=['scale'], 
#                       coords={'scale':np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                                   iso_psUf.freq_r[0].data**-1,40)/xo}
#     )
#     ssf = xr.DataArray(iso_psUf.freq_r.data**-1/xo, dims=['scale'], 
#                        coords={'scale':iso_psUf.freq_r.data**-1/xo}
#                       )
#     ssh = xr.concat([ss.where(ss>50e3/xo).dropna('scale')[::-1],
#                      ssf.where(ssf<50e3/xo).dropna('scale')
#                     ], 'scale')
#     print(len(ssf),len(ssh))
#     iso_psUw = xwavelet.wvlt_power_spectrum(
#                     uterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     ) 
#     iso_psVw = xwavelet.wvlt_power_spectrum(
#                     vterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     )
    
#     dsave = iso_psUw.to_dataset(name='U')
#     dsave['V'] = iso_psVw
#     dsave.to_zarr('/tank/topog/tuchida/Wavelet-spectrum/isoDiags_KE_region%02d_%010d.zarr' 
#                   % (reg,iiter), mode='w')
    
    dsw = xr.open_zarr(
        '/tank/topog/tuchida/Wavelet-spectrum/isoDiags_KE_region%02d_%010d.zarr' 
                       % (reg,iiter))
    iso_psUw = dsw.U
    iso_psVw = dsw.V
    _, a, b = xrft.fit_loglog((dsw.scale.sel(scale=slice(250e3,40e3))).values**-1,
                          (iso_psUw + iso_psVw
                          ).mean(['nmemb','angle']).sel(scale=slice(250e3,40e3)).values
         )
    print(a,b)
            
    w3 = (.5*(iso_psUw + iso_psVw).mean(['nmemb','angle'])
          / ((iso_psUw.scale)**-1)**-3)
    # w133 = (.5*(iso_psUw + iso_psVw).mean(['nmemb','angle'])
    #         / ((iso_psUw.scale)**-1)**(-13/3))
    w413 = (.5*(iso_psUw + iso_psVw).mean(['nmemb','angle'])
            / ((iso_psUw.scale)**-1)**(a))
    f3 = (.5*(iso_psUf + iso_psVf).mean(['nmemb'])
          / (iso_psUf.freq_r)**-3)
    # f133 = (.5*(iso_psUf + iso_psVf).mean(['nmemb'])
    #         / (iso_psUf.freq_r)**(-13/3))
    f413 = (.5*(iso_psUf + iso_psVf).mean(['nmemb'])
            / (iso_psUf.freq_r)**(a))

    
    datas = (.5*(iso_psUw + iso_psVw).sum('angle')
             * np.diff(iso_psVw.angle)[0]*2,
            )  # samples must be in a sequence
    rng = np.random.default_rng()
    Wres = bootstrap(datas, np.mean, confidence_level=0.95,
                     random_state=rng)
    datas = (.5*(iso_psUf + iso_psVf) * 2*np.pi,)  # samples must be in a sequence
    rng = np.random.default_rng()
    Fres = bootstrap(datas, np.mean, confidence_level=0.95,
                     random_state=rng)
    
    fig, (ax1,ax3) = plt.subplots(figsize=(10,4), nrows=1, ncols=2)
    fig.set_tight_layout(True)
    ax2 = ax1.twiny()
    ax4 = ax3.twiny()
    
    ax1.fill_between((iso_psUw.scale)**-1*1e3, 
                     Wres.confidence_interval.low, Wres.confidence_interval.high, 
                     alpha=.4, color='k')
    ax1.fill_between((iso_psUf.freq_r)*1e3, 
                     Fres.confidence_interval.low, Fres.confidence_interval.high, 
                     alpha=.36, color='r')
    
    ax1.plot((iso_psUw.scale)**-1*1e3, 
             .5*(iso_psUw + iso_psVw).mean(['nmemb']).sum('angle')
             * np.diff(iso_psVw.angle)[0]*2,
             'k', lw=2, label=r"Wavelet")
    ax1.plot((iso_psUf.freq_r)*1e3, 
             .5*(iso_psUf + iso_psVf).mean(['nmemb']) * 2*np.pi,
             'r', lw=2, label=r"Fourier")
    ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*6e0, 
             ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
    # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*2e0, 
    #          ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
    ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**a*4e0, 
             ls=':', c='grey', alpha=.8, label=r"$k^{-3.95}$")
            
    ax3.plot((iso_psUw.scale)**-1*1e3, w3/w3.mean(),
             'k--', label=r"$\alpha=3$")
    # ax3.plot((iso_psUw.scale)**-1*1e3, w133/w133.mean(),
    #          'k-.', label=r"$\alpha=13/3$")
    ax3.plot((iso_psUw.scale)**-1*1e3, w413/w413.mean(),
             'k:', lw=2, label=r"$\alpha=4.13$")
    ax3.plot((iso_psUf.freq_r)*1e3, f3/f3.mean(),
             'r--', label=r"")
    # ax3.plot((iso_psUf.freq_r)*1e3, f133/f133.mean(),
    #          'r-.', label=r"")
    ax3.plot((iso_psUf.freq_r)*1e3, f413/f413.mean(),
             'r:', lw=2, label=r"")

    ax1.set_xscale('log')
    ax1.set_yscale('log')
    ax3.set_xscale('log')
    ax3.set_yscale('log')
    ax2.set_xscale('log')
    ax2.set_yscale('log')
    ax4.set_xscale('log')
    ax4.set_yscale('log')
    ax1.set_ylim([1e-3,4e4])
    ax1.set_xlim([1e-3,1e-1])
    ax2.set_xlim([1e-3,1e-1])
    ax3.set_xlim([1e-3,1e-1])
    ax4.set_xlim([1e-3,1e-1])
    ax2.set_xticks([1e-3,1e-2,1e-1])
    ax2.set_xticklabels([1e3,1e2,1e1])
    ax4.set_xticks([1e-3,1e-2,1e-1])
    ax4.set_xticklabels([1e3,1e2,1e1])
    ax1.set_xlabel(r"[cpkm]", fontsize=13)
    ax2.set_xlabel(r"[km]", fontsize=13)
    ax1.set_ylabel(r"$E_K$ [(m$^2$ s$^{-2}$) / cpm]", fontsize=13)
    ax3.set_xlabel(r"[cpkm]", fontsize=13)
    ax4.set_xlabel(r"[km]", fontsize=13)
    ax3.set_ylabel(r"$E_K~/~k^{-\alpha}$", fontsize=13)
    if reg == 0:
        ax1.legend(loc='lower left', fontsize=12)
        ax3.legend(loc='lower left', fontsize=12)
    ax3.grid(True)
    plt.savefig(op.join(savedir,
        'Figs/WvsF-KE-spec_Region%02d_integrated_%010d.pdf' 
                        % (reg,iiter))
               )
    plt.show()
# Out:
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 dask.array<chunksize=(), meta=np.ndarray>
#     time     timedelta64[ns] 3295 days <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 dask.array<chunksize=(), meta=np.ndarray>
#     time     timedelta64[ns] 3295 days
# -3.947488314383441 -58.86938210806736

# %%
# reg = 3
dg = 1
nmembs = np.arange(100,148)

iiter = 1419120
# iiter = 1421280
# iiter = 1423440

for reg in range(1):
    
    dsb = open_mdsdataset(op.join(ddir,'ensm/run1967/ocn'), 
                          grid_dir=gdir,
                          prefix=['snap_diagOcn'], delta_t=2e2,
                          iters=iiter, 
                         ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                               XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                              ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
    
    for nmemb in nmembs:
        if nmemb == 100:
            ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                         % (nmemb)), 
                                 grid_dir=gdir,
                                 prefix=['snap_diagOcn'], delta_t=2e2,
                                 iters=iiter, 
                                ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                      XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                     ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
        else:
            ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                        % (nmemb)), 
                                                grid_dir=gdir,
                                                prefix=['snap_diagOcn'], delta_t=2e2,
                                                iters=iiter, 
                                               ).sel(YC=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     YG=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     XC=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12),
                                                     XG=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12)
                                                    ).chunk({'Z':1,'Zl':1,'Zu':1,
                                                             'Zp1':1}).isel(time=0)
                           ], dim='nmemb')

            # ds = ds.chunk({'nmemb':6})
    ds.coords['nmemb'] = ('nmemb',nmembs)
    # if reg == 0:
    #     print(ds)
    if len(dsb.XG) > len(dsb.XC):
        dsb = dsb.isel(XG=slice(None,-1))
        ds = ds.isel(XG=slice(None,-1))
        
    grid = Grid(ds, periodic=[])
    
    xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    ny, nx = xT.shape
    xT = xT - xT.isel(XC=nx//2)
    # (xT - xT.isel(YC=-1,XC=0)).plot()
    # plt.show()
    xT = (xT - xT.isel(YC=-1,XC=0)).values.flatten()
    yT = (yT - yT.isel(YC=0)).values.flatten()

    up = grid.interp((ds.UVEL - dsb.UVEL).where(ds.maskW!=0.),
                     'X',boundary='extend'
                    ).isel(Z=[0,18],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='XC'
                                                 ).interpolate_na(dim='YC'
                                                                 ).fillna(0.)
    vp = grid.interp((ds.VVEL - dsb.VVEL).where(ds.maskS!=0.),
                     'Y',boundary='extend'
                    ).isel(Z=[0,18],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='YC'
                                                 ).interpolate_na(dim='XC'
                                                                 ).fillna(0.)
    
    iZ = 1
    up.isel(nmemb=0,Z=iZ).plot(vmax=1, vmin=-1, cmap='RdBu_r')
    plt.show()
    
    # print(ds.dxC.mean(), ds.dyC.mean())
    dx = ds.dxC.min().values
    dy = ds.dyC.min().values
    N = up.isel(nmemb=0,Z=iZ).shape

    
    uterp = xr.DataArray(np.zeros_like(up), dims=up.dims,
                         coords={'nmemb':nmembs,
                                 'Z':up.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    vterp = xr.DataArray(np.zeros_like(vp), dims=vp.dims,
                         coords={'nmemb':nmembs,
                                 'Z':vp.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    Aterp = xr.DataArray(np.zeros_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), 
                         dims=ds.rA.dims,
                         coords={'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    #         xx, yy = np.meshgrid(np.arange(0,N[-1]*dx,dx), np.arange(0,N[-2]*dx,dx))
    xxx, yyy = np.mgrid[0:nx*dx:dx, 0:ny*dy:dy]
    for nn in range(len(nmembs)):
        for iz in range(len(up.Z)):

#             uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (up*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 

#             vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (vp*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T
            uterp[dict(nmemb=nn, Z=iz)] = griddata((xT, yT), 
                                               (up*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iz).values.flatten(),
                                               (xxx, yyy) 
                                              ).T 

            vterp[dict(nmemb=nn, Z=iz)] = griddata((xT, yT), 
                                               (vp*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iz).values.flatten(),
                                               (xxx, yyy) 
                                              ).T

    Aterp[:] = griddata((xT, yT), 
                     (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
                     (xxx, yyy) 
                    ).T
    uterp = uterp / Aterp
    vterp = vterp / Aterp
    uterp.isel(nmemb=0,Z=iZ).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
    plt.show()
    
    iso_psUf = xrft.isotropic_power_spectrum(
                    uterp.interpolate_na(dim='XC').interpolate_na(dim='YC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
    iso_psVf = xrft.isotropic_power_spectrum(
                    vterp.interpolate_na(dim='YC').interpolate_na(dim='XC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
#     ss = xr.DataArray(np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                   iso_psUf.freq_r[0].data**-1,40)/xo,
#                       dims=['scale'], 
#                       coords={'scale':np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                                   iso_psUf.freq_r[0].data**-1,40)/xo}
#     )
#     ssf = xr.DataArray(iso_psUf.freq_r.data**-1/xo, dims=['scale'], 
#                        coords={'scale':iso_psUf.freq_r.data**-1/xo}
#                       )
#     ssh = xr.concat([ss.where(ss>50e3/xo).dropna('scale')[::-1],
#                      ssf.where(ssf<50e3/xo).dropna('scale')
#                     ], 'scale')
#     # print(len(ssf),len(ssh))
#     iso_psUw = xwavelet.wvlt_power_spectrum(
#                     uterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     ) 
#     iso_psVw = xwavelet.wvlt_power_spectrum(
#                     vterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     )
    
#     dsave = iso_psUw.to_dataset(name='U')
#     dsave['V'] = iso_psVw
#     dsave.to_zarr(op.join(savedir,'isoDiags_KE_region%02d_%010d.zarr' 
#                   % (reg,iiter)), mode='w')
#     dsave.close()
    
    dsw = xr.open_zarr(op.join(savedir,'isoDiags_KE_region%02d_%010d.zarr' 
                      % (reg,iiter)))
    iso_psUw = dsw.U
    iso_psVw = dsw.V
    
    fig, (ax1,ax3) = plt.subplots(figsize=(10,4), nrows=1, ncols=2)
    fig.set_tight_layout(True)
    ax2 = ax1.twiny()
    ax4 = ax3.twiny()
    for iz in range(2):
        _, a, b = xrft.fit_loglog((dsw.scale.sel(scale=slice(250e3,80e3))).values**-1,
                                  (iso_psUw + iso_psVw
                                  ).isel(Z=iz).mean(['nmemb','angle']
                                                   ).sel(scale=slice(250e3,80e3)).values
             )
        print(a, b)

    
        datas = (.5*(iso_psUw + iso_psVw).isel(Z=iz).sum('angle')
                 * np.diff(iso_psVw.angle)[0]*2,
                )  # samples must be in a sequence
        rng = np.random.default_rng()
        Wres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
        datas = (.5*(iso_psUf + iso_psVf).isel(Z=iz) * 2*np.pi,
                )  # samples must be in a sequence
        rng = np.random.default_rng()
        Fres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
    
        if iz == 0:
            ax1.fill_between((iso_psUw.scale)**-1*1e3, 
                             Wres.confidence_interval.low, Wres.confidence_interval.high, 
                             alpha=.4, color='k')
            ax1.fill_between((iso_psUf.freq_r)*1e3, 
                             Fres.confidence_interval.low, Fres.confidence_interval.high, 
                             alpha=.36, color='r')

            ax1.plot((iso_psUw.scale)**-1*1e3, 
                     .5*(iso_psUw + iso_psVw).isel(Z=iz).mean(['nmemb']).sum('angle')
                     * np.diff(iso_psVw.angle)[0]*2,
                     'k', lw=2, label=r"Wavelet")
            ax1.plot((iso_psUf.freq_r)*1e3, 
                     .5*(iso_psUf + iso_psVf).isel(Z=iz).mean(['nmemb']) * 2*np.pi,
                     'r', lw=2, label=r"Fourier")
            ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**(-2)*6e2, 
                     ls='-.', c='grey', alpha=.8, label=r"$k^{-2}$")
            ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*.8e2, 
                     ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
            # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*2e0, 
            #          ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
            ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**a*1.5e2, 
                     ls=':', c='grey', alpha=.8, label=r"$k^{-2.73}$")
        else:
            ax3.fill_between((iso_psUw.scale)**-1*1e3, 
                             Wres.confidence_interval.low, Wres.confidence_interval.high, 
                             alpha=.4, color='k')
            ax3.fill_between((iso_psUf.freq_r)*1e3, 
                             Fres.confidence_interval.low, Fres.confidence_interval.high, 
                             alpha=.36, color='r')

            ax3.plot((iso_psUw.scale)**-1*1e3, 
                     .5*(iso_psUw + iso_psVw).isel(Z=iz).mean(['nmemb']).sum('angle')
                     * np.diff(iso_psVw.angle)[0]*2,
                     'k', lw=2, label=r"Wavelet")
            ax3.plot((iso_psUf.freq_r)*1e3, 
                     .5*(iso_psUf + iso_psVf).isel(Z=iz).mean(['nmemb']) * 2*np.pi,
                     'r', lw=2, label=r"Fourier")
            ax3.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*2e1, 
                     ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
            # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*2e0, 
            #          ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
            ax3.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**a*6e0, 
                     ls=':', c='grey', alpha=.8, label=r"$k^{-3.52}$")
            

    ax1.set_xscale('log')
    ax1.set_yscale('log')
    ax3.set_xscale('log')
    ax3.set_yscale('log')
    ax2.set_xscale('log')
    ax2.set_yscale('log')
    ax4.set_xscale('log')
    ax4.set_yscale('log')
    ax1.set_ylim([1e-1,1e5])
    ax1.set_xlim([1e-3,1e-1])
    ax2.set_xlim([1e-3,1e-1])
    ax3.set_ylim([1.5e-3,4e4])
    ax3.set_xlim([1e-3,1e-1])
    ax4.set_xlim([1e-3,1e-1])
    ax2.set_xticks([1e-3,1e-2,1e-1])
    ax2.set_xticklabels([1e3,1e2,1e1])
    ax4.set_xticks([1e-3,1e-2,1e-1])
    ax4.set_xticklabels([1e3,1e2,1e1])
    ax1.set_xlabel(r"[cpkm]", fontsize=13)
    ax2.set_xlabel(r"[km]", fontsize=13)
    ax1.set_ylabel(r"$\mathcal{K}_K$ [(m$^2\,$s$^{-2})\,/\,$cpm]", fontsize=13)
    ax3.set_xlabel(r"[cpkm]", fontsize=13)
    ax4.set_xlabel(r"[km]", fontsize=13)
    ax1.set_title(r"Surface", fontsize=14)
    ax3.set_title(r"$Z=-452\,$m", fontsize=14)
    # ax3.set_ylabel(r"$E_K~/~k^{-\alpha}$", fontsize=13)
    ax1.legend(loc='lower left', fontsize=12)
    ax3.legend(loc='lower left', fontsize=12)
    ax1.grid(True)
    ax3.grid(True)
    plt.savefig(op.join(savedir,
                        'Figs/WvsF-KE-spec_Region%02d_integrated_%010d.pdf' 
                        % (reg,iiter))
               )
    plt.show()
# Out:
# -2.731550202551621 -35.37257455306755
# -3.523021595579766 -51.46792534829056

# %%
# reg = 3
dg = 1
nmembs = np.arange(100,148)

iiters = [1421280, 1423440]
reg = 0


fig, (ax1,ax3) = plt.subplots(figsize=(10,4), nrows=1, ncols=2)
fig.set_tight_layout(True)
ax2 = ax1.twiny()
ax4 = ax3.twiny()

for iiter in iiters:
    
    dsb = open_mdsdataset(op.join(ddir,'ensm/run1967/ocn'), 
                          grid_dir=gdir,
                          prefix=['snap_diagOcn'], delta_t=2e2,
                          iters=iiter, 
                         ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                               XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                              ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
    
    for nmemb in nmembs:
        if nmemb == 100:
            ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                         % (nmemb)), 
                                 grid_dir=gdir,
                                 prefix=['snap_diagOcn'], delta_t=2e2,
                                 iters=iiter, 
                                ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                      XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                     ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
        else:
            ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                        % (nmemb)), 
                                                grid_dir=gdir,
                                                prefix=['snap_diagOcn'], delta_t=2e2,
                                                iters=iiter, 
                                               ).sel(YC=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     YG=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     XC=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12),
                                                     XG=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12)
                                                    ).chunk({'Z':1,'Zl':1,'Zu':1,
                                                             'Zp1':1}).isel(time=0)
                           ], dim='nmemb')

            # ds = ds.chunk({'nmemb':6})
    ds.coords['nmemb'] = ('nmemb',nmembs)
    # if reg == 0:
    #     print(ds)
    if len(dsb.XG) > len(dsb.XC):
        dsb = dsb.isel(XG=slice(None,-1))
        ds = ds.isel(XG=slice(None,-1))
        
    grid = Grid(ds, periodic=[])
    
    xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    ny, nx = xT.shape
    xT = xT - xT.isel(XC=nx//2)
    # (xT - xT.isel(YC=-1,XC=0)).plot()
    # plt.show()
    xT = (xT - xT.isel(YC=-1,XC=0)).values.flatten()
    yT = (yT - yT.isel(YC=0)).values.flatten()

    up = grid.interp((ds.UVEL - dsb.UVEL).where(ds.maskW!=0.),
                     'X',boundary='extend'
                    ).isel(Z=[0,18],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='XC'
                                                 ).interpolate_na(dim='YC'
                                                                 ).fillna(0.)
    vp = grid.interp((ds.VVEL - dsb.VVEL).where(ds.maskS!=0.),
                     'Y',boundary='extend'
                    ).isel(Z=[0,18],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='YC'
                                                 ).interpolate_na(dim='XC'
                                                                 ).fillna(0.)
    
    # up.isel(nmemb=0,Z=1).plot(vmax=1, vmin=-1, cmap='RdBu_r')
    # plt.show()
    
    # print(ds.dxC.mean(), ds.dyC.mean())
    dx = ds.dxC.min().values
    dy = ds.dyC.min().values
    N = up.isel(nmemb=0,Z=1).shape

    
    uterp = xr.DataArray(np.zeros_like(up), dims=up.dims,
                         coords={'nmemb':nmembs,
                                 'Z':up.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    vterp = xr.DataArray(np.zeros_like(vp), dims=vp.dims,
                         coords={'nmemb':nmembs,
                                 'Z':vp.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    Aterp = xr.DataArray(np.zeros_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), 
                         dims=ds.rA.dims,
                         coords={'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    #         xx, yy = np.meshgrid(np.arange(0,N[-1]*dx,dx), np.arange(0,N[-2]*dx,dx))
    xxx, yyy = np.mgrid[0:nx*dx:dx, 0:ny*dy:dy]
    for nn in range(len(nmembs)):
        for iz in range(len(up.Z)):

#             uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (up*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 

#             vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (vp*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T
            uterp[dict(nmemb=nn, Z=iz)] = griddata((xT, yT), 
                                               (up*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iz).values.flatten(),
                                               (xxx, yyy) 
                                              ).T 

            vterp[dict(nmemb=nn, Z=iz)] = griddata((xT, yT), 
                                               (vp*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iz).values.flatten(),
                                               (xxx, yyy) 
                                              ).T

    Aterp[:] = griddata((xT, yT), 
                     (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
                     (xxx, yyy) 
                    ).T
    uterp = uterp / Aterp
    vterp = vterp / Aterp
    # uterp.isel(nmemb=0,Z=1).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
    # plt.show()
    
    iso_psUf = xrft.isotropic_power_spectrum(
                    uterp.interpolate_na(dim='XC').interpolate_na(dim='YC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
    iso_psVf = xrft.isotropic_power_spectrum(
                    vterp.interpolate_na(dim='YC').interpolate_na(dim='XC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
#     ss = xr.DataArray(np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                   iso_psUf.freq_r[0].data**-1,40)/xo,
#                       dims=['scale'], 
#                       coords={'scale':np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                                   iso_psUf.freq_r[0].data**-1,40)/xo}
#     )
#     ssf = xr.DataArray(iso_psUf.freq_r.data**-1/xo, dims=['scale'], 
#                        coords={'scale':iso_psUf.freq_r.data**-1/xo}
#                       )
#     ssh = xr.concat([ss.where(ss>50e3/xo).dropna('scale')[::-1],
#                      ssf.where(ssf<50e3/xo).dropna('scale')
#                     ], 'scale')
#     # print(len(ssf),len(ssh))
#     iso_psUw = xwavelet.wvlt_power_spectrum(
#                     uterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     ) 
#     iso_psVw = xwavelet.wvlt_power_spectrum(
#                     vterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     )
    
#     dsave = iso_psUw.to_dataset(name='U')
#     dsave['V'] = iso_psVw
#     dsave.to_zarr(op.join(savedir,'isoDiags_KE_region%02d_%010d.zarr' 
#                   % (reg,iiter)), mode='w')
#     dsave.close()
    
    dsw = xr.open_zarr(op.join(savedir,'isoDiags_KE_region%02d_%010d.zarr' 
                      % (reg,iiter)))
    iso_psUw = dsw.U
    iso_psVw = dsw.V
    
    _, a, b = xrft.fit_loglog((dsw.scale.sel(scale=slice(250e3,80e3))).values**-1,
                                  (iso_psUw + iso_psVw
                                  ).isel(Z=iz).mean(['nmemb','angle']
                                                   ).sel(scale=slice(250e3,80e3)).values
             )
    print(a, b)

    iz = 1
    datas = (.5*(iso_psUw + iso_psVw).isel(Z=iz).sum('angle')
                 * np.diff(iso_psVw.angle)[0]*2,
                )  # samples must be in a sequence
    rng = np.random.default_rng()
    Wres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
    datas = (.5*(iso_psUf + iso_psVf).isel(Z=iz) * 2*np.pi,
                )  # samples must be in a sequence
    rng = np.random.default_rng()
    Fres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
    
    if iiter == iiters[0]:
        ax1.fill_between((iso_psUw.scale)**-1*1e3, 
                             Wres.confidence_interval.low, Wres.confidence_interval.high, 
                             alpha=.4, color='k')
        ax1.fill_between((iso_psUf.freq_r)*1e3, 
                             Fres.confidence_interval.low, Fres.confidence_interval.high, 
                             alpha=.36, color='r')

        ax1.plot((iso_psUw.scale)**-1*1e3, 
                     .5*(iso_psUw + iso_psVw).isel(Z=iz).mean(['nmemb']).sum('angle')
                     * np.diff(iso_psVw.angle)[0]*2,
                     'k', lw=2, label=r"Wavelet")
        ax1.plot((iso_psUf.freq_r)*1e3, 
                     .5*(iso_psUf + iso_psVf).isel(Z=iz).mean(['nmemb']) * 2*np.pi,
                     'r', lw=2, label=r"Fourier")
        # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**(-2)*6e2, 
        #              ls='-.', c='grey', alpha=.8, label=r"$k^{-2}$")
        ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*2e1, 
                     ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
            # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*2e0, 
            #          ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
        ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**a*1e1, 
                     ls=':', c='grey', alpha=.8, label=r"$k^{-3.44}$")
    else:
        ax3.fill_between((iso_psUw.scale)**-1*1e3, 
                             Wres.confidence_interval.low, Wres.confidence_interval.high, 
                             alpha=.4, color='k')
        ax3.fill_between((iso_psUf.freq_r)*1e3, 
                             Fres.confidence_interval.low, Fres.confidence_interval.high, 
                             alpha=.36, color='r')

        ax3.plot((iso_psUw.scale)**-1*1e3, 
                     .5*(iso_psUw + iso_psVw).isel(Z=iz).mean(['nmemb']).sum('angle')
                     * np.diff(iso_psVw.angle)[0]*2,
                     'k', lw=2, label=r"Wavelet")
        ax3.plot((iso_psUf.freq_r)*1e3, 
                     .5*(iso_psUf + iso_psVf).isel(Z=iz).mean(['nmemb']) * 2*np.pi,
                     'r', lw=2, label=r"Fourier")
        ax3.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*2e1, 
                     ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
            # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*2e0, 
            #          ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
        ax3.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**a*1e1, 
                     ls=':', c='grey', alpha=.8, label=r"$k^{-3.23}$")
            

ax1.set_xscale('log')
ax1.set_yscale('log')
ax3.set_xscale('log')
ax3.set_yscale('log')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax4.set_xscale('log')
ax4.set_yscale('log')
ax1.set_ylim([1.5e-3,4e4])
ax1.set_xlim([1e-3,1e-1])
ax2.set_xlim([1e-3,1e-1])
ax3.set_ylim([1.5e-3,4e4])
ax3.set_xlim([1e-3,1e-1])
ax4.set_xlim([1e-3,1e-1])
ax2.set_xticks([1e-3,1e-2,1e-1])
ax2.set_xticklabels([1e3,1e2,1e1])
ax4.set_xticks([1e-3,1e-2,1e-1])
ax4.set_xticklabels([1e3,1e2,1e1])
ax1.set_xlabel(r"[cpkm]", fontsize=13)
ax2.set_xlabel(r"[km]", fontsize=13)
ax1.set_ylabel(r"$\mathcal{K}_K$ [(m$^2\,$s$^{-2})\,/\,$cpm]", fontsize=13)
ax3.set_xlabel(r"[cpkm]", fontsize=13)
ax4.set_xlabel(r"[km]", fontsize=13)
ax1.set_title(r"Jan. 6", fontsize=14)
ax3.set_title(r"Jan. 11", fontsize=14)
# ax3.set_ylabel(r"$E_K~/~k^{-\alpha}$", fontsize=13)
ax1.legend(loc='lower left', fontsize=12)
ax3.legend(loc='lower left', fontsize=12)
ax1.grid(True)
ax3.grid(True)
plt.savefig(op.join(savedir,
                        'Figs/WvsF-KE-spec_Region%02d_integrated_Jan6-11.pdf' 
                        % (reg))
               )
plt.show()
# Out:
# -3.4440489605636038 -50.09593774236515
# -3.2337501391076753 -46.45866831368698

# %%
# reg = 3
dg = 1
nmembs = np.arange(100,148)

iiters = [1419120, 1421280, 1423440]
date = ['Jan. 1', 'Jan. 6', 'Jan. 11']
reg = 0


fig, ax1 = plt.subplots(figsize=(7,5))
fig.set_tight_layout(True)
ax2 = ax1.twiny()

tt = 0
for iiter in iiters:
    
    dsb = open_mdsdataset(op.join(ddir,'ensm/run1967/ocn'), 
                          grid_dir=gdir,
                          prefix=['snap_diagOcn'], delta_t=2e2,
                          iters=iiter, 
                         ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                               XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                              ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
    
    for nmemb in nmembs:
        if nmemb == 100:
            ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                         % (nmemb)), 
                                 grid_dir=gdir,
                                 prefix=['snap_diagOcn'], delta_t=2e2,
                                 iters=iiter, 
                                ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                      XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                     ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
        else:
            ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                        % (nmemb)), 
                                                grid_dir=gdir,
                                                prefix=['snap_diagOcn'], delta_t=2e2,
                                                iters=iiter, 
                                               ).sel(YC=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     YG=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     XC=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12),
                                                     XG=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12)
                                                    ).chunk({'Z':1,'Zl':1,'Zu':1,
                                                             'Zp1':1}).isel(time=0)
                           ], dim='nmemb')

            # ds = ds.chunk({'nmemb':6})
    ds.coords['nmemb'] = ('nmemb',nmembs)
    # if reg == 0:
    #     print(ds)
    if len(dsb.XG) > len(dsb.XC):
        dsb = dsb.isel(XG=slice(None,-1))
        ds = ds.isel(XG=slice(None,-1))
        
    grid = Grid(ds, periodic=[])
    
    xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    ny, nx = xT.shape
    xT = xT - xT.isel(XC=nx//2)
    # (xT - xT.isel(YC=-1,XC=0)).plot()
    # plt.show()
    xT = (xT - xT.isel(YC=-1,XC=0)).values.flatten()
    yT = (yT - yT.isel(YC=0)).values.flatten()

    up = grid.interp((ds.UVEL - dsb.UVEL).where(ds.maskW!=0.),
                     'X',boundary='extend'
                    ).isel(Z=[0,18],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='XC'
                                                 ).interpolate_na(dim='YC'
                                                                 ).fillna(0.)
    vp = grid.interp((ds.VVEL - dsb.VVEL).where(ds.maskS!=0.),
                     'Y',boundary='extend'
                    ).isel(Z=[0,18],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='YC'
                                                 ).interpolate_na(dim='XC'
                                                                 ).fillna(0.)
    
    # up.isel(nmemb=0,Z=1).plot(vmax=1, vmin=-1, cmap='RdBu_r')
    # plt.show()
    
    # print(ds.dxC.mean(), ds.dyC.mean())
    dx = ds.dxC.min().values
    dy = ds.dyC.min().values
    N = up.isel(nmemb=0,Z=1).shape

    
    uterp = xr.DataArray(np.zeros_like(up), dims=up.dims,
                         coords={'nmemb':nmembs,
                                 'Z':up.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    vterp = xr.DataArray(np.zeros_like(vp), dims=vp.dims,
                         coords={'nmemb':nmembs,
                                 'Z':vp.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    Aterp = xr.DataArray(np.zeros_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), 
                         dims=ds.rA.dims,
                         coords={'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    #         xx, yy = np.meshgrid(np.arange(0,N[-1]*dx,dx), np.arange(0,N[-2]*dx,dx))
    xxx, yyy = np.mgrid[0:nx*dx:dx, 0:ny*dy:dy]
    for nn in range(len(nmembs)):
        for iz in range(len(up.Z)):

#             uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (up*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 

#             vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (vp*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T
            uterp[dict(nmemb=nn, Z=iz)] = griddata((xT, yT), 
                                               (up*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iz).values.flatten(),
                                               (xxx, yyy) 
                                              ).T 

            vterp[dict(nmemb=nn, Z=iz)] = griddata((xT, yT), 
                                               (vp*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iz).values.flatten(),
                                               (xxx, yyy) 
                                              ).T

    Aterp[:] = griddata((xT, yT), 
                     (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
                     (xxx, yyy) 
                    ).T
    uterp = uterp / Aterp
    vterp = vterp / Aterp
    # uterp.isel(nmemb=0,Z=1).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
    # plt.show()
    
    iso_psUf = xrft.isotropic_power_spectrum(
                    uterp.interpolate_na(dim='XC').interpolate_na(dim='YC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
    iso_psVf = xrft.isotropic_power_spectrum(
                    vterp.interpolate_na(dim='YC').interpolate_na(dim='XC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
#     ss = xr.DataArray(np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                   iso_psUf.freq_r[0].data**-1,40)/xo,
#                       dims=['scale'], 
#                       coords={'scale':np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                                   iso_psUf.freq_r[0].data**-1,40)/xo}
#     )
#     ssf = xr.DataArray(iso_psUf.freq_r.data**-1/xo, dims=['scale'], 
#                        coords={'scale':iso_psUf.freq_r.data**-1/xo}
#                       )
#     ssh = xr.concat([ss.where(ss>50e3/xo).dropna('scale')[::-1],
#                      ssf.where(ssf<50e3/xo).dropna('scale')
#                     ], 'scale')
#     # print(len(ssf),len(ssh))
#     iso_psUw = xwavelet.wvlt_power_spectrum(
#                     uterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     ) 
#     iso_psVw = xwavelet.wvlt_power_spectrum(
#                     vterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     )
    
#     dsave = iso_psUw.to_dataset(name='U')
#     dsave['V'] = iso_psVw
#     dsave.to_zarr(op.join(savedir,'isoDiags_KE_region%02d_%010d.zarr' 
#                   % (reg,iiter)), mode='w')
#     dsave.close()
    
    dsw = xr.open_zarr(op.join(savedir,'isoDiags_KE_region%02d_%010d.zarr' 
                      % (reg,iiter)))
    iso_psUw = dsw.U
    iso_psVw = dsw.V
    
    _, a, b = xrft.fit_loglog((dsw.scale.sel(scale=slice(250e3,80e3))).values**-1,
                                  (iso_psUw + iso_psVw
                                  ).isel(Z=iz).mean(['nmemb','angle']
                                                   ).sel(scale=slice(250e3,80e3)).values
             )
    print(a, b)

    iz = 1
    datas = (.5*(iso_psUw + iso_psVw).isel(Z=iz).sum('angle')
                 * np.diff(iso_psVw.angle)[0]*2,
                )  # samples must be in a sequence
    rng = np.random.default_rng()
    Wres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
    datas = (.5*(iso_psUf + iso_psVf).isel(Z=iz) * 2*np.pi,
                )  # samples must be in a sequence
    rng = np.random.default_rng()
    Fres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
    
    if iiter == iiters[0]:
        ax1.fill_between((iso_psUw.scale)**-1*1e3, 
                             Wres.confidence_interval.low, Wres.confidence_interval.high, 
                             alpha=.3, color='k')

        ax1.plot((iso_psUw.scale)**-1*1e3, 
                     .5*(iso_psUw + iso_psVw).isel(Z=iz).mean(['nmemb']).sum('angle')
                     * np.diff(iso_psVw.angle)[0]*2,
                     'k', lw=2, label=date[0])

        # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**(-2)*6e2, 
        #              ls='-.', c='grey', alpha=.8, label=r"$k^{-2}$")
            # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*2e0, 
            #          ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
    else:
        ax1.fill_between((iso_psUw.scale)**-1*1e3, 
                             Wres.confidence_interval.low, Wres.confidence_interval.high, 
                             alpha=.3, )

        ax1.plot((iso_psUw.scale)**-1*1e3, 
                     .5*(iso_psUw + iso_psVw).isel(Z=iz).mean(['nmemb']).sum('angle')
                     * np.diff(iso_psVw.angle)[0]*2,
                     lw=1, label=date[tt])
    tt += 1

ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*2e1, 
                     ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
ax1.set_xscale('log')
ax1.set_yscale('log')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax1.set_ylim([1.5e-3,4e4])
ax1.set_xlim([1e-3,1e-1])
ax2.set_xlim([1e-3,1e-1])
ax2.set_xticks([1e-3,1e-2,1e-1])
ax2.set_xticklabels([1e3,1e2,1e1])
ax1.set_xlabel(r"[cpkm]", fontsize=13)
ax2.set_xlabel(r"[km]", fontsize=13)
ax1.set_ylabel(r"$\mathcal{K}_K$ [(m$^2\,$s$^{-2})\,/\,$cpm]", fontsize=13)
# ax3.set_ylabel(r"$E_K~/~k^{-\alpha}$", fontsize=13)
ax1.legend(loc='lower left', fontsize=12)
ax1.grid(True)
plt.savefig(op.join(savedir,
                        'Figs/WvsF-KE-spec_Region%02d_integrated_Jan1--11.pdf' 
                        % (reg))
               )
plt.show()
# Out:
# -3.523021595579766 -51.46792534829056
# -3.4440489605636038 -50.09593774236515
# -3.2337501391076753 -46.45866831368698

# %%
# reg = 3
dg = 1
nmembs = np.arange(100,148)

iiter = 1419120
# iiter = 1421280
# iiter = 1423440

for reg in range(5,6):
    
    dsb = open_mdsdataset(op.join(ddir,'ensm/run1967/ocn'), 
                          grid_dir=gdir,
                          prefix=['snap_diagOcn'], delta_t=2e2,
                          iters=iiter, 
                         ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                               XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                              ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
    
    for nmemb in nmembs:
        if nmemb == 100:
            ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                         % (nmemb)), 
                                 grid_dir=gdir,
                                 prefix=['snap_diagOcn'], delta_t=2e2,
                                 iters=iiter, 
                                ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                      XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                     ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
        else:
            ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                        % (nmemb)), 
                                                grid_dir=gdir,
                                                prefix=['snap_diagOcn'], delta_t=2e2,
                                                iters=iiter, 
                                               ).sel(YC=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     YG=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     XC=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12),
                                                     XG=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12)
                                                    ).chunk({'Z':1,'Zl':1,'Zu':1,
                                                             'Zp1':1}).isel(time=0)
                           ], dim='nmemb')

            # ds = ds.chunk({'nmemb':6})
    ds.coords['nmemb'] = ('nmemb',nmembs)
    # if reg == 0:
    #     print(ds)
    if len(dsb.XG) > len(dsb.XC):
        dsb = dsb.isel(XG=slice(None,-1))
        ds = ds.isel(XG=slice(None,-1))
        
    grid = Grid(ds, periodic=[])
    
    xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    ny, nx = xT.shape
    xT = xT - xT.isel(XC=nx//2)
    # (xT - xT.isel(YC=-1,XC=0)).plot()
    # plt.show()
    xT = (xT - xT.isel(YC=-1,XC=0)).values.flatten()
    yT = (yT - yT.isel(YC=0)).values.flatten()

    up = grid.interp((ds.UVEL - dsb.UVEL).where(ds.maskW!=0.),
                     'X',boundary='extend'
                    ).isel(Z=[0,18],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='XC'
                                                 ).interpolate_na(dim='YC'
                                                                 ).fillna(0.)
    vp = grid.interp((ds.VVEL - dsb.VVEL).where(ds.maskS!=0.),
                     'Y',boundary='extend'
                    ).isel(Z=[0,18],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='YC'
                                                 ).interpolate_na(dim='XC'
                                                                 ).fillna(0.)
    
    iZ = 1
    up.isel(nmemb=0,Z=iZ).plot(vmax=.4, vmin=-.4, cmap='RdBu_r')
    plt.show()
    
    # print(ds.dxC.mean(), ds.dyC.mean())
    dx = ds.dxC.min().values
    dy = ds.dyC.min().values
    N = up.isel(nmemb=0,Z=iZ).shape

    
    uterp = xr.DataArray(np.zeros_like(up), dims=up.dims,
                         coords={'nmemb':nmembs,
                                 'Z':up.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    vterp = xr.DataArray(np.zeros_like(vp), dims=vp.dims,
                         coords={'nmemb':nmembs,
                                 'Z':vp.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    Aterp = xr.DataArray(np.zeros_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), 
                         dims=ds.rA.dims,
                         coords={'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    #         xx, yy = np.meshgrid(np.arange(0,N[-1]*dx,dx), np.arange(0,N[-2]*dx,dx))
    xxx, yyy = np.mgrid[0:nx*dx:dx, 0:ny*dy:dy]
    for nn in range(len(nmembs)):
        for iz in range(len(up.Z)):

#             uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (up*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 

#             vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (vp*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T
            uterp[dict(nmemb=nn, Z=iz)] = griddata((xT, yT), 
                                               (up*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iz).values.flatten(),
                                               (xxx, yyy) 
                                              ).T 

            vterp[dict(nmemb=nn, Z=iz)] = griddata((xT, yT), 
                                               (vp*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iz).values.flatten(),
                                               (xxx, yyy) 
                                              ).T

    Aterp[:] = griddata((xT, yT), 
                     (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
                     (xxx, yyy) 
                    ).T
    uterp = uterp / Aterp
    vterp = vterp / Aterp
    uterp.isel(nmemb=0,Z=iZ).plot(vmax=.4, vmin=-.4, cmap='RdBu_r', rasterized=True)
    plt.show()
    
    iso_psUf = xrft.isotropic_power_spectrum(
                    uterp.interpolate_na(dim='XC').interpolate_na(dim='YC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
    iso_psVf = xrft.isotropic_power_spectrum(
                    vterp.interpolate_na(dim='YC').interpolate_na(dim='XC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
#     ss = xr.DataArray(np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                   iso_psUf.freq_r[0].data**-1,40)/xo,
#                       dims=['scale'], 
#                       coords={'scale':np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                                   iso_psUf.freq_r[0].data**-1,40)/xo}
#     )
#     ssf = xr.DataArray(iso_psUf.freq_r.data**-1/xo, dims=['scale'], 
#                        coords={'scale':iso_psUf.freq_r.data**-1/xo}
#                       )
#     ssh = xr.concat([ss.where(ss>50e3/xo).dropna('scale')[::-1],
#                      ssf.where(ssf<50e3/xo).dropna('scale')
#                     ], 'scale')
#     # print(len(ssf),len(ssh))
#     iso_psUw = xwavelet.wvlt_power_spectrum(
#                     uterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     ) 
#     iso_psVw = xwavelet.wvlt_power_spectrum(
#                     vterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     )
    
#     dsave = iso_psUw.to_dataset(name='U')
#     dsave['V'] = iso_psVw
#     dsave.to_zarr(op.join(savedir,'isoDiags_KE_region%02d_%010d.zarr' 
#                   % (reg,iiter)), mode='w')
#     dsave.close()
    
    dsw = xr.open_zarr(op.join(savedir,'isoDiags_KE_region%02d_%010d.zarr' 
                      % (reg,iiter)))
    iso_psUw = dsw.U
    iso_psVw = dsw.V
    
    fig, (ax1,ax3) = plt.subplots(figsize=(10,4), nrows=1, ncols=2)
    fig.set_tight_layout(True)
    ax2 = ax1.twiny()
    ax4 = ax3.twiny()
    for iz in range(2):
        _, a, b = xrft.fit_loglog((dsw.scale.sel(scale=slice(250e3,80e3))).values**-1,
                                  (iso_psUw + iso_psVw
                                  ).isel(Z=iz).mean(['nmemb','angle']
                                                   ).sel(scale=slice(250e3,80e3)).values
             )
        print(a, b)

    
        datas = (.5*(iso_psUw + iso_psVw).isel(Z=iz).sum('angle')
                 * np.diff(iso_psVw.angle)[0]*2,
                )  # samples must be in a sequence
        rng = np.random.default_rng()
        Wres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
        datas = (.5*(iso_psUf + iso_psVf).isel(Z=iz) * 2*np.pi,)  # samples must be in a sequence
        rng = np.random.default_rng()
        Fres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
    
        if iz == 0:
            ax1.fill_between((iso_psUw.scale)**-1*1e3, 
                             Wres.confidence_interval.low, Wres.confidence_interval.high, 
                             alpha=.4, color='k')
            ax1.fill_between((iso_psUf.freq_r)*1e3, 
                             Fres.confidence_interval.low, Fres.confidence_interval.high, 
                             alpha=.36, color='r')

            ax1.plot((iso_psUw.scale)**-1*1e3, 
                     .5*(iso_psUw + iso_psVw).isel(Z=iz).mean(['nmemb']).sum('angle')
                     * np.diff(iso_psVw.angle)[0]*2,
                     'k', lw=2, label=r"Wavelet")
            ax1.plot((iso_psUf.freq_r)*1e3, 
                     .5*(iso_psUf + iso_psVf).isel(Z=iz).mean(['nmemb']) * 2*np.pi,
                     'r', lw=2, label=r"Fourier")
            ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**(-2)*1e1, 
                     ls='-.', c='grey', alpha=.8, label=r"$k^{-2}$")
            ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*1e0, 
                     ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
            # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*2e0, 
            #          ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
            ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**a*1.5e0, 
                     ls=':', c='grey', alpha=.8, label=r"$k^{-2.88}$")
        else:
            ax3.fill_between((iso_psUw.scale)**-1*1e3, 
                             Wres.confidence_interval.low, Wres.confidence_interval.high, 
                             alpha=.4, color='k')
            ax3.fill_between((iso_psUf.freq_r)*1e3, 
                             Fres.confidence_interval.low, Fres.confidence_interval.high, 
                             alpha=.36, color='r')

            ax3.plot((iso_psUw.scale)**-1*1e3, 
                     .5*(iso_psUw + iso_psVw).isel(Z=iz).mean(['nmemb']).sum('angle')
                     * np.diff(iso_psVw.angle)[0]*2,
                     'k', lw=2, label=r"Wavelet")
            ax3.plot((iso_psUf.freq_r)*1e3, 
                     .5*(iso_psUf + iso_psVf).isel(Z=iz).mean(['nmemb']) * 2*np.pi,
                     'r', lw=2, label=r"Fourier")
            ax3.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*2e-1, 
                     ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
            # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*2e0, 
            #          ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
            ax3.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**a*2e-1, 
                     ls=':', c='grey', alpha=.8, label=r"$k^{-3.59}$")
            

    ax1.set_xscale('log')
    ax1.set_yscale('log')
    ax3.set_xscale('log')
    ax3.set_yscale('log')
    ax2.set_xscale('log')
    ax2.set_yscale('log')
    ax4.set_xscale('log')
    ax4.set_yscale('log')
    ax1.set_ylim([5e-4,2e3])
    ax1.set_xlim([1e-3,1e-1])
    ax2.set_xlim([1e-3,1e-1])
    ax3.set_ylim([2e-6,7e2])
    ax3.set_xlim([1e-3,1e-1])
    ax4.set_xlim([1e-3,1e-1])
    ax2.set_xticks([1e-3,1e-2,1e-1])
    ax2.set_xticklabels([1e3,1e2,1e1])
    ax4.set_xticks([1e-3,1e-2,1e-1])
    ax4.set_xticklabels([1e3,1e2,1e1])
    ax1.set_xlabel(r"[cpkm]", fontsize=13)
    ax2.set_xlabel(r"[km]", fontsize=13)
    ax1.set_ylabel(r"$\mathcal{K}_K$ [(m$^2\,$s$^{-2})\,/\,$cpm]", fontsize=13)
    ax3.set_xlabel(r"[cpkm]", fontsize=13)
    ax4.set_xlabel(r"[km]", fontsize=13)
    ax1.set_title(r"Surface", fontsize=14)
    ax3.set_title(r"$Z=-452\,$m", fontsize=14)
    # ax3.set_ylabel(r"$E_K~/~k^{-\alpha}$", fontsize=13)
    ax1.legend(loc='lower left', fontsize=12)
    ax3.legend(loc='lower left', fontsize=12)
    ax1.grid(True)
    ax3.grid(True)
    plt.savefig(op.join(savedir,
                        'Figs/WvsF-KE-spec_Region%02d_integrated_%010d.pdf' 
                        % (reg,iiter))
               )
    plt.show()
# Out:
# -2.8821844414454345 -43.81634538331402
# -3.5930061906149975 -58.58127624595567

# %%
# reg = 3
dg = 1
nmembs = np.arange(100,148)

iiters = [1421280, 1423440]
reg = 5


fig, (ax1,ax3) = plt.subplots(figsize=(10,4), nrows=1, ncols=2)
fig.set_tight_layout(True)
ax2 = ax1.twiny()
ax4 = ax3.twiny()

for iiter in iiters:
    
    dsb = open_mdsdataset(op.join(ddir,'ensm/run1967/ocn'), 
                          grid_dir=gdir,
                          prefix=['snap_diagOcn'], delta_t=2e2,
                          iters=iiter, 
                         ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                               XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                              ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
    
    for nmemb in nmembs:
        if nmemb == 100:
            ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                         % (nmemb)), 
                                 grid_dir=gdir,
                                 prefix=['snap_diagOcn'], delta_t=2e2,
                                 iters=iiter, 
                                ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                      XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                     ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
        else:
            ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                        % (nmemb)), 
                                                grid_dir=gdir,
                                                prefix=['snap_diagOcn'], delta_t=2e2,
                                                iters=iiter, 
                                               ).sel(YC=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     YG=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     XC=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12),
                                                     XG=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12)
                                                    ).chunk({'Z':1,'Zl':1,'Zu':1,
                                                             'Zp1':1}).isel(time=0)
                           ], dim='nmemb')

            # ds = ds.chunk({'nmemb':6})
    ds.coords['nmemb'] = ('nmemb',nmembs)
    # if reg == 0:
    #     print(ds)
    if len(dsb.XG) > len(dsb.XC):
        dsb = dsb.isel(XG=slice(None,-1))
        ds = ds.isel(XG=slice(None,-1))
        
    grid = Grid(ds, periodic=[])
    
    xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    ny, nx = xT.shape
    xT = xT - xT.isel(XC=nx//2)
    # (xT - xT.isel(YC=-1,XC=0)).plot()
    # plt.show()
    xT = (xT - xT.isel(YC=-1,XC=0)).values.flatten()
    yT = (yT - yT.isel(YC=0)).values.flatten()

    up = grid.interp((ds.UVEL - dsb.UVEL).where(ds.maskW!=0.),
                     'X',boundary='extend'
                    ).isel(Z=[0,18],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='XC'
                                                 ).interpolate_na(dim='YC'
                                                                 ).fillna(0.)
    vp = grid.interp((ds.VVEL - dsb.VVEL).where(ds.maskS!=0.),
                     'Y',boundary='extend'
                    ).isel(Z=[0,18],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='YC'
                                                 ).interpolate_na(dim='XC'
                                                                 ).fillna(0.)
    
    # up.isel(nmemb=0,Z=1).plot(vmax=1, vmin=-1, cmap='RdBu_r')
    # plt.show()
    
    # print(ds.dxC.mean(), ds.dyC.mean())
    dx = ds.dxC.min().values
    dy = ds.dyC.min().values
    N = up.isel(nmemb=0,Z=1).shape

    
    uterp = xr.DataArray(np.zeros_like(up), dims=up.dims,
                         coords={'nmemb':nmembs,
                                 'Z':up.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    vterp = xr.DataArray(np.zeros_like(vp), dims=vp.dims,
                         coords={'nmemb':nmembs,
                                 'Z':vp.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    Aterp = xr.DataArray(np.zeros_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), 
                         dims=ds.rA.dims,
                         coords={'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    #         xx, yy = np.meshgrid(np.arange(0,N[-1]*dx,dx), np.arange(0,N[-2]*dx,dx))
    xxx, yyy = np.mgrid[0:nx*dx:dx, 0:ny*dy:dy]
    for nn in range(len(nmembs)):
        for iz in range(len(up.Z)):

#             uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (up*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 

#             vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (vp*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T
            uterp[dict(nmemb=nn, Z=iz)] = griddata((xT, yT), 
                                               (up*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iz).values.flatten(),
                                               (xxx, yyy) 
                                              ).T 

            vterp[dict(nmemb=nn, Z=iz)] = griddata((xT, yT), 
                                               (vp*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iz).values.flatten(),
                                               (xxx, yyy) 
                                              ).T

    Aterp[:] = griddata((xT, yT), 
                     (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
                     (xxx, yyy) 
                    ).T
    uterp = uterp / Aterp
    vterp = vterp / Aterp
    # uterp.isel(nmemb=0,Z=1).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
    # plt.show()
    
    iso_psUf = xrft.isotropic_power_spectrum(
                    uterp.interpolate_na(dim='XC').interpolate_na(dim='YC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
    iso_psVf = xrft.isotropic_power_spectrum(
                    vterp.interpolate_na(dim='YC').interpolate_na(dim='XC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
#     ss = xr.DataArray(np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                   iso_psUf.freq_r[0].data**-1,40)/xo,
#                       dims=['scale'], 
#                       coords={'scale':np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                                   iso_psUf.freq_r[0].data**-1,40)/xo}
#     )
#     ssf = xr.DataArray(iso_psUf.freq_r.data**-1/xo, dims=['scale'], 
#                        coords={'scale':iso_psUf.freq_r.data**-1/xo}
#                       )
#     ssh = xr.concat([ss.where(ss>50e3/xo).dropna('scale')[::-1],
#                      ssf.where(ssf<50e3/xo).dropna('scale')
#                     ], 'scale')
#     # print(len(ssf),len(ssh))
#     iso_psUw = xwavelet.wvlt_power_spectrum(
#                     uterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     ) 
#     iso_psVw = xwavelet.wvlt_power_spectrum(
#                     vterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     )
    
#     dsave = iso_psUw.to_dataset(name='U')
#     dsave['V'] = iso_psVw
#     dsave.to_zarr(op.join(savedir,'isoDiags_KE_region%02d_%010d.zarr' 
#                   % (reg,iiter)), mode='w')
#     dsave.close()
    
    dsw = xr.open_zarr(op.join(savedir,'isoDiags_KE_region%02d_%010d.zarr' 
                      % (reg,iiter)))
    iso_psUw = dsw.U
    iso_psVw = dsw.V
    
    _, a, b = xrft.fit_loglog((dsw.scale.sel(scale=slice(250e3,80e3))).values**-1,
                                  (iso_psUw + iso_psVw
                                  ).isel(Z=iz).mean(['nmemb','angle']
                                                   ).sel(scale=slice(250e3,80e3)).values
             )
    print(a, b)

    iz = 1
    datas = (.5*(iso_psUw + iso_psVw).isel(Z=iz).sum('angle')
                 * np.diff(iso_psVw.angle)[0]*2,
                )  # samples must be in a sequence
    rng = np.random.default_rng()
    Wres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
    datas = (.5*(iso_psUf + iso_psVf).isel(Z=iz) * 2*np.pi,
                )  # samples must be in a sequence
    rng = np.random.default_rng()
    Fres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
    
    if iiter == iiters[0]:
        ax1.fill_between((iso_psUw.scale)**-1*1e3, 
                             Wres.confidence_interval.low, Wres.confidence_interval.high, 
                             alpha=.4, color='k')
        ax1.fill_between((iso_psUf.freq_r)*1e3, 
                             Fres.confidence_interval.low, Fres.confidence_interval.high, 
                             alpha=.36, color='r')

        ax1.plot((iso_psUw.scale)**-1*1e3, 
                     .5*(iso_psUw + iso_psVw).isel(Z=iz).mean(['nmemb']).sum('angle')
                     * np.diff(iso_psVw.angle)[0]*2,
                     'k', lw=2, label=r"Wavelet")
        ax1.plot((iso_psUf.freq_r)*1e3, 
                     .5*(iso_psUf + iso_psVf).isel(Z=iz).mean(['nmemb']) * 2*np.pi,
                     'r', lw=2, label=r"Fourier")
        # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**(-2)*6e2, 
        #              ls='-.', c='grey', alpha=.8, label=r"$k^{-2}$")
        ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*2e-1, 
                     ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
            # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*2e0, 
            #          ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
        ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**a*2e-1, 
                     ls=':', c='grey', alpha=.8, label=r"$k^{-3.60}$")
    else:
        ax3.fill_between((iso_psUw.scale)**-1*1e3, 
                             Wres.confidence_interval.low, Wres.confidence_interval.high, 
                             alpha=.4, color='k')
        ax3.fill_between((iso_psUf.freq_r)*1e3, 
                             Fres.confidence_interval.low, Fres.confidence_interval.high, 
                             alpha=.36, color='r')

        ax3.plot((iso_psUw.scale)**-1*1e3, 
                     .5*(iso_psUw + iso_psVw).isel(Z=iz).mean(['nmemb']).sum('angle')
                     * np.diff(iso_psVw.angle)[0]*2,
                     'k', lw=2, label=r"Wavelet")
        ax3.plot((iso_psUf.freq_r)*1e3, 
                     .5*(iso_psUf + iso_psVf).isel(Z=iz).mean(['nmemb']) * 2*np.pi,
                     'r', lw=2, label=r"Fourier")
        ax3.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*2e-1, 
                     ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
            # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*2e0, 
            #          ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
        ax3.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**a*2e-1, 
                     ls=':', c='grey', alpha=.8, label=r"$k^{-3.66}$")
            

ax1.set_xscale('log')
ax1.set_yscale('log')
ax3.set_xscale('log')
ax3.set_yscale('log')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax4.set_xscale('log')
ax4.set_yscale('log')
ax1.set_ylim([2e-6,7e2])
ax1.set_xlim([1e-3,1e-1])
ax2.set_xlim([1e-3,1e-1])
ax3.set_ylim([2e-6,7e2])
ax3.set_xlim([1e-3,1e-1])
ax4.set_xlim([1e-3,1e-1])
ax2.set_xticks([1e-3,1e-2,1e-1])
ax2.set_xticklabels([1e3,1e2,1e1])
ax4.set_xticks([1e-3,1e-2,1e-1])
ax4.set_xticklabels([1e3,1e2,1e1])
ax1.set_xlabel(r"[cpkm]", fontsize=13)
ax2.set_xlabel(r"[km]", fontsize=13)
ax1.set_ylabel(r"$\mathcal{K}_K$ [(m$^2\,$s$^{-2})\,/\,$cpm]", fontsize=13)
ax3.set_xlabel(r"[cpkm]", fontsize=13)
ax4.set_xlabel(r"[km]", fontsize=13)
ax1.set_title(r"Jan. 6", fontsize=14)
ax3.set_title(r"Jan. 11", fontsize=14)
# ax3.set_ylabel(r"$E_K~/~k^{-\alpha}$", fontsize=13)
ax1.legend(loc='lower left', fontsize=12)
ax3.legend(loc='lower left', fontsize=12)
ax1.grid(True)
ax3.grid(True)
plt.savefig(op.join(savedir,
                        'Figs/WvsF-KE-spec_Region%02d_integrated_Jan6-11.pdf' 
                        % (reg))
               )
plt.show()
# Out:
# -3.597179847526081 -58.70711776164655
# -3.663176113890564 -59.88472121428324

# %%
# reg = 3
dg = 1
nmembs = np.arange(100,148)

iiters = [1419120, 1421280, 1423440]
date = ['Jan. 1', 'Jan. 6', 'Jan. 11']
reg = 5


fig, ax1 = plt.subplots(figsize=(7,5))
fig.set_tight_layout(True)
ax2 = ax1.twiny()

tt = 0
for iiter in iiters:
    
    dsb = open_mdsdataset(op.join(ddir,'ensm/run1967/ocn'), 
                          grid_dir=gdir,
                          prefix=['snap_diagOcn'], delta_t=2e2,
                          iters=iiter, 
                         ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                               XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                              ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
    
    for nmemb in nmembs:
        if nmemb == 100:
            ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                         % (nmemb)), 
                                 grid_dir=gdir,
                                 prefix=['snap_diagOcn'], delta_t=2e2,
                                 iters=iiter, 
                                ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                      XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                     ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
        else:
            ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                        % (nmemb)), 
                                                grid_dir=gdir,
                                                prefix=['snap_diagOcn'], delta_t=2e2,
                                                iters=iiter, 
                                               ).sel(YC=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     YG=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     XC=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12),
                                                     XG=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12)
                                                    ).chunk({'Z':1,'Zl':1,'Zu':1,
                                                             'Zp1':1}).isel(time=0)
                           ], dim='nmemb')

            # ds = ds.chunk({'nmemb':6})
    ds.coords['nmemb'] = ('nmemb',nmembs)
    # if reg == 0:
    #     print(ds)
    if len(dsb.XG) > len(dsb.XC):
        dsb = dsb.isel(XG=slice(None,-1))
        ds = ds.isel(XG=slice(None,-1))
        
    grid = Grid(ds, periodic=[])
    
    xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    ny, nx = xT.shape
    xT = xT - xT.isel(XC=nx//2)
    # (xT - xT.isel(YC=-1,XC=0)).plot()
    # plt.show()
    xT = (xT - xT.isel(YC=-1,XC=0)).values.flatten()
    yT = (yT - yT.isel(YC=0)).values.flatten()

    up = grid.interp((ds.UVEL - dsb.UVEL).where(ds.maskW!=0.),
                     'X',boundary='extend'
                    ).isel(Z=[0,18],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='XC'
                                                 ).interpolate_na(dim='YC'
                                                                 ).fillna(0.)
    vp = grid.interp((ds.VVEL - dsb.VVEL).where(ds.maskS!=0.),
                     'Y',boundary='extend'
                    ).isel(Z=[0,18],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='YC'
                                                 ).interpolate_na(dim='XC'
                                                                 ).fillna(0.)
    
    # up.isel(nmemb=0,Z=1).plot(vmax=1, vmin=-1, cmap='RdBu_r')
    # plt.show()
    
    # print(ds.dxC.mean(), ds.dyC.mean())
    dx = ds.dxC.min().values
    dy = ds.dyC.min().values
    N = up.isel(nmemb=0,Z=1).shape

    
    uterp = xr.DataArray(np.zeros_like(up), dims=up.dims,
                         coords={'nmemb':nmembs,
                                 'Z':up.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    vterp = xr.DataArray(np.zeros_like(vp), dims=vp.dims,
                         coords={'nmemb':nmembs,
                                 'Z':vp.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    Aterp = xr.DataArray(np.zeros_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), 
                         dims=ds.rA.dims,
                         coords={'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    #         xx, yy = np.meshgrid(np.arange(0,N[-1]*dx,dx), np.arange(0,N[-2]*dx,dx))
    xxx, yyy = np.mgrid[0:nx*dx:dx, 0:ny*dy:dy]
    for nn in range(len(nmembs)):
        for iz in range(len(up.Z)):

#             uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (up*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 

#             vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (vp*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T
            uterp[dict(nmemb=nn, Z=iz)] = griddata((xT, yT), 
                                               (up*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iz).values.flatten(),
                                               (xxx, yyy) 
                                              ).T 

            vterp[dict(nmemb=nn, Z=iz)] = griddata((xT, yT), 
                                               (vp*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iz).values.flatten(),
                                               (xxx, yyy) 
                                              ).T

    Aterp[:] = griddata((xT, yT), 
                     (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
                     (xxx, yyy) 
                    ).T
    uterp = uterp / Aterp
    vterp = vterp / Aterp
    # uterp.isel(nmemb=0,Z=1).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
    # plt.show()
    
    iso_psUf = xrft.isotropic_power_spectrum(
                    uterp.interpolate_na(dim='XC').interpolate_na(dim='YC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
    iso_psVf = xrft.isotropic_power_spectrum(
                    vterp.interpolate_na(dim='YC').interpolate_na(dim='XC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ) 
#     ss = xr.DataArray(np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                   iso_psUf.freq_r[0].data**-1,40)/xo,
#                       dims=['scale'], 
#                       coords={'scale':np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                                   iso_psUf.freq_r[0].data**-1,40)/xo}
#     )
#     ssf = xr.DataArray(iso_psUf.freq_r.data**-1/xo, dims=['scale'], 
#                        coords={'scale':iso_psUf.freq_r.data**-1/xo}
#                       )
#     ssh = xr.concat([ss.where(ss>50e3/xo).dropna('scale')[::-1],
#                      ssf.where(ssf<50e3/xo).dropna('scale')
#                     ], 'scale')
#     # print(len(ssf),len(ssh))
#     iso_psUw = xwavelet.wvlt_power_spectrum(
#                     uterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     ) 
#     iso_psVw = xwavelet.wvlt_power_spectrum(
#                     vterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     )
    
#     dsave = iso_psUw.to_dataset(name='U')
#     dsave['V'] = iso_psVw
#     dsave.to_zarr(op.join(savedir,'isoDiags_KE_region%02d_%010d.zarr' 
#                   % (reg,iiter)), mode='w')
#     dsave.close()
    
    dsw = xr.open_zarr(op.join(savedir,'isoDiags_KE_region%02d_%010d.zarr' 
                      % (reg,iiter)))
    iso_psUw = dsw.U
    iso_psVw = dsw.V
    
    _, a, b = xrft.fit_loglog((dsw.scale.sel(scale=slice(250e3,80e3))).values**-1,
                                  (iso_psUw + iso_psVw
                                  ).isel(Z=iz).mean(['nmemb','angle']
                                                   ).sel(scale=slice(250e3,80e3)).values
             )
    print(a, b)

    iz = 1
    datas = (.5*(iso_psUw + iso_psVw).isel(Z=iz).sum('angle')
                 * np.diff(iso_psVw.angle)[0]*2,
                )  # samples must be in a sequence
    rng = np.random.default_rng()
    Wres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
    datas = (.5*(iso_psUf + iso_psVf).isel(Z=iz) * 2*np.pi,
                )  # samples must be in a sequence
    rng = np.random.default_rng()
    Fres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
    
    if iiter == iiters[0]:
        ax1.fill_between((iso_psUw.scale)**-1*1e3, 
                             Wres.confidence_interval.low, Wres.confidence_interval.high, 
                             alpha=.3, color='k')

        ax1.plot((iso_psUw.scale)**-1*1e3, 
                     .5*(iso_psUw + iso_psVw).isel(Z=iz).mean(['nmemb']).sum('angle')
                     * np.diff(iso_psVw.angle)[0]*2,
                     'k', lw=2, label=date[0])

        # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**(-2)*6e2, 
        #              ls='-.', c='grey', alpha=.8, label=r"$k^{-2}$")
            # ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*2e0, 
            #          ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
    else:
        ax1.fill_between((iso_psUw.scale)**-1*1e3, 
                             Wres.confidence_interval.low, Wres.confidence_interval.high, 
                             alpha=.3, )

        ax1.plot((iso_psUw.scale)**-1*1e3, 
                     .5*(iso_psUw + iso_psVw).isel(Z=iz).mean(['nmemb']).sum('angle')
                     * np.diff(iso_psVw.angle)[0]*2,
                     lw=1, label=date[tt])
    tt += 1

ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*2e-1, 
                     ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
ax1.set_xscale('log')
ax1.set_yscale('log')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax1.set_ylim([2e-6,7e2])
ax1.set_xlim([1e-3,1e-1])
ax2.set_xlim([1e-3,1e-1])
ax2.set_xticks([1e-3,1e-2,1e-1])
ax2.set_xticklabels([1e3,1e2,1e1])
ax1.set_xlabel(r"[cpkm]", fontsize=13)
ax2.set_xlabel(r"[km]", fontsize=13)
ax1.set_ylabel(r"$\mathcal{K}_K$ [(m$^2\,$s$^{-2})\,/\,$cpm]", fontsize=13)
# ax3.set_ylabel(r"$E_K~/~k^{-\alpha}$", fontsize=13)
ax1.legend(loc='lower left', fontsize=12)
ax1.grid(True)
plt.savefig(op.join(savedir,
                        'Figs/WvsF-KE-spec_Region%02d_integrated_Jan1--11.pdf' 
                        % (reg))
               )
plt.show()
# Out:
# -3.5930061906149975 -58.58127624595567
# -3.597179847526081 -58.70711776164655
# -3.663176113890564 -59.88472121428324

# %%
# reg = 3
dg = 1
nmembs = np.arange(100,148)

iiter = 1419120
# iiter = 1421280
# iiter = 1423440

for reg in range(len(xs)-5):
    
    dsb = open_mdsdataset(op.join(ddir,'ensm/run1967/ocn'), 
                          grid_dir=gdir,
                          prefix=['snap_diagOcn'], delta_t=2e2,
                          iters=iiter, 
                         ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                               XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                               XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                              ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
    
    for nmemb in nmembs:
        if nmemb == 100:
            ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                         % (nmemb)), 
                                 grid_dir=gdir,
                                 prefix=['snap_diagOcn'], delta_t=2e2,
                                 iters=iiter, 
                                ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                      XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                      XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                     ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1}).isel(time=0)
        else:
            ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                        % (nmemb)), 
                                                grid_dir=gdir,
                                                prefix=['snap_diagOcn'], delta_t=2e2,
                                                iters=iiter, 
                                               ).sel(YC=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     YG=slice(ys[reg]-5-dg/12,
                                                              ys[reg]+5+dg/12),
                                                     XC=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12),
                                                     XG=slice(xs[reg]-5-dg/12,
                                                              xs[reg]+5+dg/12)
                                                    ).chunk({'Z':1,'Zl':1,'Zu':1,
                                                             'Zp1':1}).isel(time=0)
                           ], dim='nmemb')

            # ds = ds.chunk({'nmemb':6})
    ds.coords['nmemb'] = ('nmemb',nmembs)
    # if reg == 0:
    #     print(ds)
    if len(dsb.XG) > len(dsb.XC):
        dsb = dsb.isel(XG=slice(None,-1))
        ds = ds.isel(XG=slice(None,-1))
        
    grid = Grid(ds, periodic=[])
    
    xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    ny, nx = xT.shape
    xT = xT - xT.isel(XC=nx//2)
    # (xT - xT.isel(YC=-1,XC=0)).plot()
    # plt.show()
    xT = (xT - xT.isel(YC=-1,XC=0)).values.flatten()
    yT = (yT - yT.isel(YC=0)).values.flatten()

    up = grid.interp((ds.UVEL - dsb.UVEL).where(ds.maskW!=0.),
                     'X',boundary='extend'
                    ).isel(Z=[0],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='XC'
                                                 ).interpolate_na(dim='YC'
                                                                 ).fillna(0.)
    vp = grid.interp((ds.VVEL - dsb.VVEL).where(ds.maskS!=0.),
                     'Y',boundary='extend'
                    ).isel(Z=[0],YC=slice(dg,-dg),XC=slice(dg,-dg)
                          ).load().interpolate_na(dim='YC'
                                                 ).interpolate_na(dim='XC'
                                                                 ).fillna(0.)
    up.isel(nmemb=0).plot(vmax=1, vmin=-1, cmap='RdBu_r')
    plt.show()
    
    print(ds.dxC.mean(), ds.dyC.mean())
    dx = ds.dxC.min().values
    dy = ds.dyC.min().values
    N = up.isel(nmemb=0,Z=0).shape

    uterp = xr.DataArray(np.zeros_like(up), dims=up.dims,
                         coords={'nmemb':nmembs,
                                 # 'Z':up.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    vterp = xr.DataArray(np.zeros_like(vp), dims=vp.dims,
                         coords={'nmemb':nmembs,
                                 # 'Z':vp.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    Aterp = xr.DataArray(np.zeros_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), 
                         dims=ds.rA.dims,
                         coords={'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
                        )
    #         xx, yy = np.meshgrid(np.arange(0,N[-1]*dx,dx), np.arange(0,N[-2]*dx,dx))
    xxx, yyy = np.mgrid[0:nx*dx:dx, 0:ny*dy:dy]
    for nn in range(len(nmembs)):
#         for iz in range(len(up.Z)):

#             uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (up*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 

#             vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (vp*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T
        uterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
                                           (up*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                           ).isel(nmemb=nn).values.flatten(),
                                           (xxx, yyy) 
                                          ).T 

        vterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
                                           (vp*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                           ).isel(nmemb=nn).values.flatten(),
                                           (xxx, yyy) 
                                          ).T

    Aterp = griddata((xT, yT), 
                     (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
                     (xxx, yyy) 
                    ).T
    uterp = uterp / Aterp
    vterp = vterp / Aterp
    uterp.isel(nmemb=0).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
    plt.show()
    
    iso_psUf = xrft.isotropic_power_spectrum(
                    uterp.interpolate_na(dim='XC').interpolate_na(dim='YC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ).isel(Z=0)
    iso_psVf = xrft.isotropic_power_spectrum(
                    vterp.interpolate_na(dim='YC').interpolate_na(dim='XC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
    ).isel(Z=0)
    # ss = xr.DataArray(np.linspace(iso_psUf.freq_r[-1].data**-1,
    #                               iso_psUf.freq_r[0].data**-1,40)/xo,
#                       dims=['scale'], 
#                       coords={'scale':np.linspace(iso_psUf.freq_r[-1].data**-1,
#                                                   iso_psUf.freq_r[0].data**-1,40)/xo}
#     )
#     ssf = xr.DataArray(iso_psUf.freq_r.data**-1/xo, dims=['scale'], 
#                        coords={'scale':iso_psUf.freq_r.data**-1/xo}
#                       )
#     ssh = xr.concat([ss.where(ss>50e3/xo).dropna('scale')[::-1],
#                      ssf.where(ssf<50e3/xo).dropna('scale')
#                     ], 'scale')
#     print(len(ssf),len(ssh))
#     iso_psUw = xwavelet.wvlt_power_spectrum(
#                     uterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     ) 
#     iso_psVw = xwavelet.wvlt_power_spectrum(
#                     vterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
#                     xo=xo, ntheta=ntheta
#     )
    
#     dsave = iso_psUw.to_dataset(name='U')
#     dsave['V'] = iso_psVw
    # dsave.to_zarr(
    #     '/tank/topog/tuchida/Wavelet-spectrum/isoDiags_KE_region%02d_Z000_%010d.zarr' 
#                   % (reg,iiter), mode='w')
    
    dsw = xr.open_zarr(
        '/tank/topog/tuchida/Wavelet-spectrum/isoDiags_KE_region%02d_Z000_%010d.zarr' 
                       % (reg,iiter))
    iso_psUw = dsw.U.isel(Z=0)
    iso_psVw = dsw.V.isel(Z=0)
    print(xrft.fit_loglog((dsw.scale.sel(scale=slice(250e3,40e3))).values**-1,
                          (iso_psUw + iso_psVw
                          ).mean(['nmemb','angle']).sel(scale=slice(250e3,40e3)).values
         ))
            
    w3 = (.5*(iso_psUw + iso_psVw).mean(['nmemb','angle'])
          / ((iso_psUw.scale)**-1)**-3)
    w133 = (.5*(iso_psUw + iso_psVw).mean(['nmemb','angle'])
            / ((iso_psUw.scale)**-1)**(-13/3))
    w413 = (.5*(iso_psUw + iso_psVw).mean(['nmemb','angle'])
            / ((iso_psUw.scale)**-1)**(-3.48))
    f3 = (.5*(iso_psUf + iso_psVf).mean(['nmemb'])
          / (iso_psUf.freq_r)**-3)
    f133 = (.5*(iso_psUf + iso_psVf).mean(['nmemb'])
            / (iso_psUf.freq_r)**(-13/3))
    f413 = (.5*(iso_psUf + iso_psVf).mean(['nmemb'])
            / (iso_psUf.freq_r)**(-3.48))

    
    datas = (.5*(iso_psUw + iso_psVw).sum('angle')
             * np.diff(iso_psVw.angle)[0]*2,
            )  # samples must be in a sequence
    rng = np.random.default_rng()
    Wres = bootstrap(datas, np.mean, confidence_level=0.95,
                     random_state=rng)
    datas = (.5*(iso_psUf + iso_psVf) * 2*np.pi,)  # samples must be in a sequence
    rng = np.random.default_rng()
    Fres = bootstrap(datas, np.mean, confidence_level=0.95,
                     random_state=rng)
    
    fig, (ax1,ax3) = plt.subplots(figsize=(10,4), nrows=1, ncols=2)
    fig.set_tight_layout(True)
    ax2 = ax1.twiny()
    ax4 = ax3.twiny()
    
    ax1.fill_between((iso_psUw.scale)**-1*1e3, 
                     Wres.confidence_interval.low, Wres.confidence_interval.high, 
                     alpha=.4, color='k')
    ax1.fill_between((iso_psUf.freq_r)*1e3, 
                     Fres.confidence_interval.low, Fres.confidence_interval.high, 
                     alpha=.36, color='r')
    
    ax1.plot((iso_psUw.scale)**-1*1e3, 
             .5*(iso_psUw + iso_psVw).mean(['nmemb']).sum('angle')
             * np.diff(iso_psVw.angle)[0]*2,
             'k', lw=2, label=r"Wavelet")
    ax1.plot((iso_psUf.freq_r)*1e3, 
             .5*(iso_psUf + iso_psVf).mean(['nmemb']) * 2*np.pi,
             'r', lw=2, label=r"Fourier")
    ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*5e1, 
             ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
    ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(13/3)*7e0, 
             ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
    ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-(3.48)*2e1, 
             ls=':', c='grey', alpha=.8, label=r"$k^{-3.48}$")
            
    ax3.plot((iso_psUw.scale)**-1*1e3, w3/w3.mean(),
             'k--', label=r"$\alpha=3$")
    ax3.plot((iso_psUw.scale)**-1*1e3, w133/w133.mean(),
             'k-.', label=r"$\alpha=13/3$")
    ax3.plot((iso_psUw.scale)**-1*1e3, w413/w413.mean(),
             'k:', lw=2, label=r"$\alpha=3.48$")
    ax3.plot((iso_psUf.freq_r)*1e3, f3/f3.mean(),
             'r--', label=r"")
    ax3.plot((iso_psUf.freq_r)*1e3, f133/f133.mean(),
             'r-.', label=r"")
    ax3.plot((iso_psUf.freq_r)*1e3, f413/f413.mean(),
             'r:', lw=2, label=r"")

    ax1.set_xscale('log')
    ax1.set_yscale('log')
    ax3.set_xscale('log')
    ax3.set_yscale('log')
    ax2.set_xscale('log')
    ax2.set_yscale('log')
    ax4.set_xscale('log')
    ax4.set_yscale('log')
    ax1.set_ylim([2e-2,3e5])
    ax1.set_xlim([1e-3,1e-1])
    ax2.set_xlim([1e-3,1e-1])
    ax3.set_xlim([1e-3,1e-1])
    ax4.set_xlim([1e-3,1e-1])
    ax2.set_xticks([1e-3,1e-2,1e-1])
    ax2.set_xticklabels([1e3,1e2,1e1])
    ax4.set_xticks([1e-3,1e-2,1e-1])
    ax4.set_xticklabels([1e3,1e2,1e1])
    ax1.set_xlabel(r"[cpkm]", fontsize=13)
    ax2.set_xlabel(r"[km]", fontsize=13)
    ax1.set_ylabel(r"$E_K$ [(m$^2$ s$^{-2}$) / cpm]", fontsize=13)
    ax3.set_xlabel(r"[cpkm]", fontsize=13)
    ax4.set_xlabel(r"[km]", fontsize=13)
    ax3.set_ylabel(r"$E_K~/~k^{-\alpha}$", fontsize=13)
    if reg == 0:
        ax1.legend(loc='lower left', fontsize=12)
        ax3.legend(loc='lower left', fontsize=12)
    ax3.grid(True)
    plt.savefig(op.join(
    '/tank/topog/tuchida/Wavelet-spectrum/Figs/WvsF-KE-spec_Region%02d_integrated_Z000_%010d.pdf' 
                        % (reg,iiter))
               )
    plt.show()
# Out:
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 dask.array<chunksize=(), meta=np.ndarray>
#     time     timedelta64[ns] 3285 days <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 dask.array<chunksize=(), meta=np.ndarray>
#     time     timedelta64[ns] 3285 days
# (array([15862.16597538, 13462.32922232, 11333.3395426 ,  9456.0457347 ,
#         7811.76126735,  6382.27690656,  5149.8744092 ,  4097.34144171,
#         3207.9879175 ,  2465.66399252,  1854.78001894,  1360.32883875,
#          967.9109125 ,   663.76293837,   434.7908511 ,   268.60844429,
#          153.58341939,    78.89359838,    37.52577829]), -3.4847749999620747, -48.46930062664187)

# %%
fig, ax = plt.subplots()
ax.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3, 
        ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
ax.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**(-13/3)*2e-1, 
        ls=':', c='grey', alpha=.8, label=r"$k^{-13/3}$")
ax.plot((iso_psUw.scale)**-1*1e3, 
        ((iso_psUw.scale/xo)**-1)**-3*np.log((iso_psUw.scale)**-1*xo*10)**(-1/3), 
        c='grey', alpha=.8, label=r"$\log(kx_0)^{-1/3}k^{-3}$")
ax.set_xscale('log')
ax.set_yscale('log')
ax.legend(loc='lower left')

# %%
reg_start = 1
dg = 1
nmembs = np.arange(100,148)

iZ = 0

for reg in range(1,2):
    if reg == reg_start:
        itimes = ntimes[0,:1]
    else:
        itimes = ntimes[0]
    for ii in itimes:
        dsb = open_mdsdataset(op.join(ddir,'ensm/run1967/ocn'), 
                              grid_dir=gdir,
                              prefix=['snap_diagOcn'], delta_t=2e2,
                              iters=ii, 
                             ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                   YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                   XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                   XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                  ).isel(time=0).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1})

        for nmemb in nmembs:
            if nmemb == 100:
                ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                             % (nmemb)), 
                                     grid_dir=gdir,
                                     prefix=['snap_diagOcn'], delta_t=2e2,
                                     iters=ii, 
                                    ).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                          YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                          XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                          XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                         ).isel(time=0).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1})
            else:
                ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                            % (nmemb)), 
                                                    grid_dir=gdir,
                                                    prefix=['snap_diagOcn'], delta_t=2e2,
                                                    iters=ii, 
                                                   ).sel(YC=slice(ys[reg]-5-dg/12,
                                                                  ys[reg]+5+dg/12),
                                                         YG=slice(ys[reg]-5-dg/12,
                                                                  ys[reg]+5+dg/12),
                                                         XC=slice(xs[reg]-5-dg/12,
                                                                  xs[reg]+5+dg/12),
                                                         XG=slice(xs[reg]-5-dg/12,
                                                                  xs[reg]+5+dg/12)
                                                        ).isel(time=0).chunk({'Z':1,'Zl':1,
                                                                              'Zu':1,
                                                                 'Zp1':1})
                               ], dim='nmemb')

        ds.coords['nmemb'] = ('nmemb',nmembs)
        # if reg == 0:
        #     print(ds)
        if len(dsb.XG) > len(dsb.XC):
            dsb = dsb.isel(XG=slice(None,-1))
            ds = ds.isel(XG=slice(None,-1))

        grid = Grid(ds, periodic=[])

        xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),
                                                            XC=slice(dg,-dg))
        yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),
                                                            XC=slice(dg,-dg))
        ny, nx = xT.shape
        xT = xT - xT.isel(XC=nx//2)
        # (xT - xT.isel(YC=-1,XC=0)).plot()
        # plt.show()
        xT = (xT - xT.isel(YC=-1,XC=0)).values.flatten()
        yT = (yT - yT.isel(YC=0)).values.flatten()

        up = grid.interp((ds.UVEL - dsb.UVEL),
                         'X',boundary='extend'
                        ).where(ds.maskC!=0.).isel(Z=[0,18],YC=slice(dg,-dg),
                                                   XC=slice(dg,-dg)
                              ).load().interpolate_na(dim='XC'
                                                     ).interpolate_na(dim='YC'
                                                                     ).fillna(0.)
        vp = grid.interp((ds.VVEL - dsb.VVEL),
                         'Y',boundary='extend'
                        ).where(ds.maskC!=0.).isel(Z=[0,18],YC=slice(dg,-dg),
                                                   XC=slice(dg,-dg)
                              ).load().interpolate_na(dim='YC'
                                                     ).interpolate_na(dim='XC'
                                                                     ).fillna(0.)
        # up.isel(nmemb=0,Z=1).plot(vmax=.8, vmin=-.8, cmap='RdBu_r', rasterized=True)
        # plt.show()

        dx = ds.dxC.min().values
        dy = ds.dyC.min().values
        N = up.isel(nmemb=0,Z=0).shape

        uterp = xr.DataArray(np.zeros_like(up.isel(Z=iZ)), dims=up.isel(Z=iZ).dims,
                             coords={'nmemb':nmembs,
                                     # 'Z':up.Z,
                                     'YC':np.arange(0,N[-2]*dy,dy),
                                     'XC':np.arange(0,N[-1]*dx,dx)}
                            )
        vterp = xr.DataArray(np.zeros_like(vp.isel(Z=iZ)), dims=vp.isel(Z=iZ).dims,
                             coords={'nmemb':nmembs,
                                     # 'Z':vp.Z,
                                     'YC':np.arange(0,N[-2]*dy,dy),
                                     'XC':np.arange(0,N[-1]*dx,dx)}
                            )
        Aterp = xr.DataArray(np.zeros_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), 
                             dims=ds.rA.dims,
                             coords={'YC':np.arange(0,N[-2]*dy,dy),
                                     'XC':np.arange(0,N[-1]*dx,dx)}
                            )

        xxx, yyy = np.mgrid[0:nx*dx:dx, 0:ny*dy:dy]
        for nn in range(len(nmembs)):

            uterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
                                               (up*ds.rA.isel(YC=slice(dg,-dg),
                                                              XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iZ).values.flatten(),
                                               (xxx, yyy) 
                                              ).T 

            vterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
                                               (vp*ds.rA.isel(YC=slice(dg,-dg),
                                                              XC=slice(dg,-dg))
                                               ).isel(nmemb=nn,Z=iZ).values.flatten(),
                                               (xxx, yyy) 
                                              ).T

        Aterp = griddata((xT, yT), 
                         (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
                         (xxx, yyy) 
                        ).T
        uterp = uterp / Aterp
        vterp = vterp / Aterp
        # uterp.isel(nmemb=0).plot(vmax=.8, vmin=-.8, cmap='RdBu_r', rasterized=True)
        # plt.show()

        iso_psUf = xrft.isotropic_power_spectrum(
                        uterp.interpolate_na(dim='XC').interpolate_na(dim='YC').fillna(0.), 
                        dim=["YC", "XC"], window='hann', 
                        window_correction=True, true_amplitude=True, truncate=True
        ) 
        iso_psVf = xrft.isotropic_power_spectrum(
                        vterp.interpolate_na(dim='YC').interpolate_na(dim='XC').fillna(0.), 
                        dim=["YC", "XC"], window='hann', 
                        window_correction=True, true_amplitude=True, truncate=True
        )
        dsave = iso_psUf.to_dataset(name='U')
        dsave['V'] = iso_psVf
        dsave.to_zarr(op.join(savedir,
                              'Z0000/Points/%s/%010d/isoDiags_fEKE.zarr' 
                              % (sreg[reg],ii)), mode='w')
        dsave.close()
        ss = xr.DataArray(np.linspace(iso_psUf.freq_r[-1].data**-1,
                                      iso_psUf.freq_r[0].data**-1,40
                                     ) / xo,
                          dims=['scale'], 
                          coords={'scale':np.linspace(iso_psUf.freq_r[-1].data**-1,
                                                      iso_psUf.freq_r[0].data**-1,40
                                                     ) / xo}
        )
        ssf = xr.DataArray(iso_psUf.freq_r.data**-1/xo, dims=['scale'], 
                           coords={'scale':iso_psUf.freq_r.data**-1/xo}
                          )
        ssh = xr.concat([ss.where(ss>50e3/xo).dropna('scale')[::-1],
                         ssf.where(ssf<50e3/xo).dropna('scale')
                        ], 'scale')
        # print(len(ssf),len(ssh))
        iso_psUw = xwavelet.wvlt_power_spectrum(
                        uterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
                        xo=xo, ntheta=ntheta
        ) 
        iso_psVw = xwavelet.wvlt_power_spectrum(
                        vterp.chunk({'nmemb':1}), ssh, dim=["YC", "XC"], 
                        xo=xo, ntheta=ntheta
        )

        dsave = iso_psUw.to_dataset(name='U')
        dsave['V'] = iso_psVw
        dsave.to_zarr(op.join(savedir,
                              'Z0000/Points/%s/%010d/isoDiags_wEKE.zarr' 
                              % (sreg[reg],ii)), mode='w')
        dsave.close()
        print(ii)
# Out:
# /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/xwavelet/wavelet.py:296: FutureWarning: This function has been renamed and will disappear in the future. Please use `power_spectrum` instead.
#   warnings.warn(msg, FutureWarning)
# /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/xwavelet/wavelet.py:296: FutureWarning: This function has been renamed and will disappear in the future. Please use `power_spectrum` instead.
#   warnings.warn(msg, FutureWarning)
# 1419120

# %%
reg = 0
dg = 1
nmembs = np.arange(100,148)
amps = [.1,.03,.01,.002,.001,.001]

for reg in range(len(xs)):
    
    dsw = xr.open_zarr(
        '/tank/topog/tuchida/Wavelet-spectrum/isoDiags_KE_region%02d_1967-01-01.zarr'
                       % reg)
    iso_psUw = dsw.U
    iso_psVw = dsw.V
    dks = xr.DataArray(np.abs(np.diff(dsw.scale**-1)).data, dims='scale',
                       coords={'scale':.5*(dsw.scale[1:].data + dsw.scale[:-1].data)}
                      ).interp(scale=dsw.scale, kwargs={"fill_value":"extrapolate"})
    E = .5*((iso_psUw + iso_psVw) * dks).sum('scale').mean('nmemb')
    iM = np.argmax(E.data)
    im = np.argmin(E.data)
    
    angles = np.linspace(0,180,18,endpoint=False)
    colors = ['k','brown','pink','lime','purple','gold',
              'olive','b','orange','magenta','r','g',
              'violet','cyan','aquamarine','peru','indianred','royalblue'
             ]
    fig, ax1 = plt.subplots(figsize=(6,4))
    fig.set_tight_layout(True)
    ax2 = ax1.twiny()
    
    for ag in np.array([iM,im]):
        
        datas = (.5*(iso_psUw + iso_psVw).isel(angle=ag)*2,
                )  # samples must be in a sequence
        rng = np.random.default_rng()
        Wres = bootstrap(datas, np.mean, confidence_level=0.95,
                         random_state=rng)
        ax1.fill_between((iso_psUw.scale)**-1*1e3, 
                         Wres.confidence_interval.low, Wres.confidence_interval.high, 
                         alpha=.35, color=colors[ag])
    
        ax1.plot((iso_psUw.scale)**-1*1e3, 
                 .5*(iso_psUw + iso_psVw).isel(angle=ag).mean(['nmemb'])
                 *2,
                 lw=2, c=colors[ag], label=r"$-$%3d$^\circ$" % angles[ag])
    if reg == 0:
        ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*8e1*amps[reg],
                 ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
        # ax1.plot((iso_psUw.scale)**-1*1e3, 
        #          ((iso_psUw.scale/xo)**-1)**-(13/3)*1e0*amps[reg], 
        #              ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
    else:
        ax1.plot((iso_psUw.scale)**-1*1e3, ((iso_psUw.scale/xo)**-1)**-3*8e1*amps[reg],
                 ls='--', c='grey', alpha=.8,)
        # ax1.plot((iso_psUw.scale)**-1*1e3, 
        #          ((iso_psUw.scale/xo)**-1)**-(13/3)*1e0*amps[reg], 
        #          ls='-.', c='grey', alpha=.8,)
            

    ax1.set_xscale('log')
    ax1.set_yscale('log')
    ax2.set_xscale('log')
    ax2.set_yscale('log')
    ax1.set_xlim([1e-3,1e-1])
    ax2.set_xlim([1e-3,1e-1])
    ax2.set_xticks([1e-3,1e-2,1e-1])
    ax2.set_xticklabels([1e3,1e2,1e1])
    ax1.set_xlabel(r"[cpkm]", fontsize=13)
    ax2.set_xlabel(r"[km]", fontsize=13)
    ax1.set_ylabel(r"$\mathcal{K}_K (\phi)$ [(m$^2\,$s$^{-2})\,/\,$cpm]", fontsize=13)
    # if reg == 0:
    ax1.legend(loc='lower left', fontsize=12)
    ax1.grid(True)
    plt.savefig(op.join(
        '/tank/spectre/tuchida/NA-wavelets/Figs/Wavelet-KE-spec_Region%02d_angles_Z452.pdf' 
                        % reg)
               )
    plt.show()
    plt.close()

# %%
sA = []
sB = []
sC = []
sD = []
sE = []
sF = []
for ii in ntimes[0,:]:
    dsA = xr.open_zarr(op.join(savedir,
                                   'Z0000/Points/%s/%010d/isoDiags_wEKE.zarr' 
                                   % (sreg[0],ii)))
    iso_psUw = dsA.U
    iso_psVw = dsA.V
    _, a, _ = xrft.fit_loglog((dsA.scale.sel(scale=slice(250e3,80e3))).values**-1,
                              (iso_psUw + iso_psVw
                              ).mean(['nmemb','angle']).sel(scale=slice(250e3,80e3)).values
             )
    sA.append(a)
    dsA.close()
    # dsB = xr.open_zarr(op.join(savedir,
    #                                'Z0000/Points/%s/%010d/isoDiags_wEKE.zarr' 
    #                                % (sreg[1],ii)))
    # iso_psUw = dsB.U
    # iso_psVw = dsB.V
    # _, a, _ = xrft.fit_loglog((dsB.scale.sel(scale=slice(250e3,50e3))).values**-1,
    #                           (iso_psUw + iso_psVw
    #                           ).mean(['nmemb','angle']).sel(scale=slice(250e3,50e3)).values
    #          )
    # sB.append(a)
    # dsB.close()
    # dsC = xr.open_zarr(op.join(savedir,
    #                                'Z0000/Points/%s/%010d/isoDiags_wEKE.zarr' 
    #                                % (sreg[2],ii)))
    # iso_psUw = dsC.U
    # iso_psVw = dsC.V
    # _, a, _ = xrft.fit_loglog((dsC.scale.sel(scale=slice(250e3,50e3))).values**-1,
    #                           (iso_psUw + iso_psVw
    #                           ).mean(['nmemb','angle']).sel(scale=slice(250e3,50e3)).values
    #          )
    # sC.append(a)
    # dsC.close()
    # dsD = xr.open_zarr(op.join(savedir,
    #                                'Z0000/Points/%s/%010d/isoDiags_wEKE.zarr' 
    #                                % (sreg[3],ii)))
    # iso_psUw = dsD.U
    # iso_psVw = dsD.V
    # _, a, _ = xrft.fit_loglog((dsD.scale.sel(scale=slice(250e3,50e3))).values**-1,
    #                           (iso_psUw + iso_psVw
    #                           ).mean(['nmemb','angle']).sel(scale=slice(250e3,50e3)).values
    #          )
    # sD.append(a)
    # dsD.close()
    # dsE = xr.open_zarr(op.join(savedir,
    #                                'Z0000/Points/%s/%010d/isoDiags_wEKE.zarr' 
    #                                % (sreg[4],ii)))
    # iso_psUw = dsE.U
    # iso_psVw = dsE.V
    # _, a, _ = xrft.fit_loglog((dsE.scale.sel(scale=slice(250e3,50e3))).values**-1,
    #                           (iso_psUw + iso_psVw
    #                           ).mean(['nmemb','angle']).sel(scale=slice(250e3,50e3)).values
    #          )
    # sE.append(a)
    # dsE.close()
    dsF = xr.open_zarr(op.join(savedir,
                                   'Z0000/Points/%s/%010d/isoDiags_wEKE.zarr' 
                                   % (sreg[5],ii)))
    iso_psUw = dsF.U
    iso_psVw = dsF.V
    _, a, _ = xrft.fit_loglog((dsF.scale.sel(scale=slice(250e3,80e3))).values**-1,
                              (iso_psUw + iso_psVw
                              ).mean(['nmemb','angle']).sel(scale=slice(250e3,80e3)).values
             )
    sF.append(a)
    dsF.close()
    
sF
# Out:
# [-2.8821844322015937,
#  -2.8244628402556056,
#  -2.804523245964956,
#  -2.79806527173941,
#  -2.795478603083294,
#  -2.6239189696198055,
#  -2.7109113010021115,
#  -2.6340526733782488,
#  -2.524232155709954,
#  -2.505532053760311,
#  -2.5534181741802913,
#  -2.6686598187866055,
#  -2.624075210542252,
#  -2.779150198673222,
#  -2.483791951776869,
#  -2.4383290618217326,
#  -2.36553233314286,
#  -2.3173273470895337,
#  -2.3888226377490827,
#  -2.3305059905641046,
#  -2.1935881949836484,
#  -2.259426951294972,
#  -2.209742619166557,
#  -2.353884683804842,
#  -2.504925793041206,
#  -2.6264245524317404,
#  -2.556682887048925,
#  -2.5338134947838182,
#  -2.5780688896838457,
#  -2.544597312996911,
#  -2.5576837511837924,
#  -2.6057835842510615,
#  -2.4493609423712184,
#  -2.4672812067278835,
#  -2.5264834662286884,
#  -2.5819765269030506,
#  -2.7368096472956194,
#  -2.82834174800758,
#  -2.755938537287912,
#  -2.7159037077246,
#  -2.7361877058199724,
#  -2.9927798456895682,
#  -2.982466742720784,
#  -3.015673562203636,
#  -2.9036276681117053,
#  -2.9960024803562764,
#  -3.031628419441378,
#  -3.1581995713369624,
#  -3.2192532748534557,
#  -3.2304948254706987,
#  -3.0840945634911483,
#  -3.083307726992512,
#  -3.131694783039209,
#  -3.1094074843267854,
#  -2.9301077687711565,
#  -2.8217687986795825,
#  -3.0251487228113216,
#  -3.026465315136405,
#  -2.7965902068968043,
#  -2.852450708905342,
#  -2.849354144196285,
#  -2.8600053210344605,
#  -2.867538847007096,
#  -2.79852918598355,
#  -2.7472778077808417,
#  -2.684611807044107,
#  -2.6706535296899223,
#  -2.519387720609163,
#  -2.63201375960995,
#  -2.807293514510032,
#  -2.7086596818909414,
#  -2.576920553304469,
#  -2.7042923886488874]

# %%
sAi = []
sBi = []
sCi = []
sDi = []
sEi = []
sFi = []
for ii in ntimes[0,:]:
    dsA = xr.open_zarr(op.join(savedir,
                                   'Z0452/Points/%s/%010d/isoDiags_wEKE.zarr' 
                                   % (sreg[0],ii)))
    iso_psUw = dsA.U
    iso_psVw = dsA.V
    _, a, _ = xrft.fit_loglog((dsA.scale.sel(scale=slice(250e3,80e3))).values**-1,
                              (iso_psUw + iso_psVw
                              ).mean(['nmemb','angle']).sel(scale=slice(250e3,80e3)).values
             )
    sAi.append(a)
    dsA.close()
    # dsB = xr.open_zarr(op.join(savedir,
    #                                'Z0452/Points/%s/%010d/isoDiags_wEKE.zarr' 
    #                                % (sreg[1],ii)))
    # iso_psUw = dsB.U
    # iso_psVw = dsB.V
    # _, a, _ = xrft.fit_loglog((dsB.scale.sel(scale=slice(250e3,50e3))).values**-1,
    #                           (iso_psUw + iso_psVw
    #                           ).mean(['nmemb','angle']).sel(scale=slice(250e3,50e3)).values
    #          )
    # sBi.append(a)
    # dsB.close()
    # dsC = xr.open_zarr(op.join(savedir,
    #                                'Z0452/Points/%s/%010d/isoDiags_wEKE.zarr' 
    #                                % (sreg[2],ii)))
    # iso_psUw = dsC.U
    # iso_psVw = dsC.V
    # _, a, _ = xrft.fit_loglog((dsC.scale.sel(scale=slice(250e3,50e3))).values**-1,
    #                           (iso_psUw + iso_psVw
    #                           ).mean(['nmemb','angle']).sel(scale=slice(250e3,50e3)).values
    #          )
    # sCi.append(a)
    # dsC.close()
    # dsD = xr.open_zarr(op.join(savedir,
    #                                'Z0452/Points/%s/%010d/isoDiags_wEKE.zarr' 
    #                                % (sreg[3],ii)))
    # iso_psUw = dsD.U
    # iso_psVw = dsD.V
    # _, a, _ = xrft.fit_loglog((dsD.scale.sel(scale=slice(250e3,50e3))).values**-1,
    #                           (iso_psUw + iso_psVw
    #                           ).mean(['nmemb','angle']).sel(scale=slice(250e3,50e3)).values
    #          )
    # sDi.append(a)
    # dsD.close()
    # dsE = xr.open_zarr(op.join(savedir,
    #                                'Z0452/Points/%s/%010d/isoDiags_wEKE.zarr' 
    #                                % (sreg[4],ii)))
    # iso_psUw = dsE.U
    # iso_psVw = dsE.V
    # _, a, _ = xrft.fit_loglog((dsE.scale.sel(scale=slice(250e3,50e3))).values**-1,
    #                           (iso_psUw + iso_psVw
    #                           ).mean(['nmemb','angle']).sel(scale=slice(250e3,50e3)).values
    #          )
    # sEi.append(a)
    # dsE.close()
    dsF = xr.open_zarr(op.join(savedir,
                                   'Z0452/Points/%s/%010d/isoDiags_wEKE.zarr' 
                                   % (sreg[5],ii)))
    iso_psUw = dsF.U
    iso_psVw = dsF.V
    _, a, _ = xrft.fit_loglog((dsF.scale.sel(scale=slice(250e3,80e3))).values**-1,
                              (iso_psUw + iso_psVw
                              ).mean(['nmemb','angle']).sel(scale=slice(250e3,80e3)).values
             )
    sFi.append(a)
    dsF.close()
    
sFi
# Out:
# [-3.593006185547917,
#  -3.5971798389678815,
#  -3.6631761064205177,
#  -3.611831955556183,
#  -3.458779267736322,
#  -3.692387316156381,
#  -3.3720484539244366,
#  -3.377947977252312,
#  -3.4334070865409996,
#  -3.483341855595862,
#  -3.6317447646820114,
#  -3.6152718754531694,
#  -3.7441246044251555,
#  -3.732061354239644,
#  -3.8242958428701215,
#  -3.69807260017455,
#  -3.642267815239485,
#  -3.4545697777322237,
#  -3.4296110775843203,
#  -3.4914650197930888,
#  -3.6155089289203457,
#  -3.516973342358076,
#  -3.4962956888562893,
#  -3.487059743928938,
#  -3.36744959059924,
#  -3.4775039567853807,
#  -3.546200590474163,
#  -3.4999119592374366,
#  -3.6135182008388176,
#  -3.5986788231993265,
#  -3.735349534859528,
#  -3.604183892087254,
#  -3.602193243062055,
#  -3.549312414650515,
#  -3.5721988558681357,
#  -3.640233594240858,
#  -3.796933644204799,
#  -3.9346593904936435,
#  -3.924323591567122,
#  -3.911425501958025,
#  -3.9816064661726682,
#  -3.814345100899348,
#  -3.8337989061969115,
#  -3.9136827547693454,
#  -3.967510973670599,
#  -3.9537867658958206,
#  -4.01963965687943,
#  -3.998648549660155,
#  -4.090931926417268,
#  -3.975242797572155,
#  -3.9682382076276395,
#  -3.926713766875497,
#  -3.9768596231671864,
#  -3.8231245093459156,
#  -3.839567967056757,
#  -3.7581412580539797,
#  -3.5646971367291993,
#  -3.4175857289061042,
#  -3.23816204159536,
#  -3.24104451986321,
#  -3.4754586767277824,
#  -3.5095548209383955,
#  -3.6233729649170807,
#  -3.508744719377741,
#  -3.2448545713736743,
#  -3.238500343315475,
#  -3.4442875262111095,
#  -3.353606096865163,
#  -3.514531608049993,
#  -3.4896781368979966,
#  -3.4111999307228498,
#  -3.381250121536542,
#  -3.1831853836929596]

# %%
from datetime import datetime, timedelta
time = np.arange(datetime(1967,1,1), datetime(1967,12,31), timedelta(days=5)).astype(datetime)

fig, ax = plt.subplots(figsize=(9,3))
fig.set_tight_layout(True)
ax2 = ax.twinx()
ax.plot(time, sAi, label=r"A")
# ax.plot(time, sB, label=r"B")
# ax.plot(time, sC, label=r"C")
# ax.plot(time, sD, label=r"D")
# ax.plot(time, sE, label=r"E")
ax.plot(time, sFi, label=r"B")

ax2.plot(time, sA, ls='--', label=r"A")
# ax2.plot(time, sBi, ls='--', label=r"B")
# ax2.plot(time, sCi, ls='--', label=r"C")
# ax2.plot(time, sDi, ls='--', label=r"D")
# ax2.plot(time, sEi, ls='--', label=r"E")
ax2.plot(time, sF, ls='--', label=r"B")

ax.legend(loc='lower left', fontsize=11)

ax.set_ylim([-4.1,-2.2])
ax2.set_ylim([-4.1,-2.2])

ax.set_ylabel(r"Slopes", fontsize=12)
ax.grid(True)

plt.savefig(op.join(savedir, 'Figs/EKEslopes_AB_250-80.pdf'))

# %%
nmembs = np.arange(100,148)
xchunk = 100
ychunk = 100
dg = 1

yy = yystart
locs = ['A','B','C','D','E','F']

fig, ax = plt.subplots(figsize=(6,5))
fig.set_tight_layout(True)
ax2 = ax.twiny()
for reg in range(len(xs)):
    dsb = open_mdsdataset(op.join(ddir,'ensm/run1967/ocn'), 
                                  grid_dir=gdir,
                                  prefix=['snap_diagOcn'], delta_t=2e2,
                                  iters=1419120, 
                                 ).isel(time=0).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                                    YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                                    XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                                    XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                                   )
    
    ds0 = xr.open_dataset(op.join(savedir,'isoDiags_u_region%02d_1967-01-01.zarr' % reg))
    ds1 = xr.open_dataset(op.join(savedir,'isoDiags_v_region%02d_1967-01-01.zarr' % reg))
    ds4 = xr.open_dataset(op.join(savedir,'isoDiags-MtE_region%02d_1967-01-01.zarr' % reg))
    dks = xr.DataArray(np.abs(np.diff(ds1.scale**-1)).data, dims='scale',
                       coords={'scale':.5*(ds1.scale[1:].data + ds1.scale[:-1].data)}
                      ).interp(scale=ds1.scale, kwargs={"fill_value": "extrapolate"})
    Ak = (ds0.iso_uA + ds1.iso_vA
          - (ds4.iso_uA + ds4.iso_vA))
    piw = ((Ak) * dks).cumsum('scale').mean('nmemb')
    piw = piw.where((piw.scale)**-1<1e-5).sum('scale',skipna=True).compute()
    
    for nmemb in nmembs:
        if nmemb == 100:
            ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                         % (nmemb)), 
                                 grid_dir=gdir,
                                 prefix=['snap_diagOcn'], delta_t=2e2,
                                 iters=1419120, 
                                ).isel(time=0).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                                   YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
                                                   XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
                                                   XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
                                                  )
        else:
            ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                        % (nmemb)), 
                                                grid_dir=gdir,
                                                prefix=['snap_diagOcn'], delta_t=2e2,
                                                iters=1419120, 
                                               ).isel(time=0).sel(YC=slice(ys[reg]-5-dg/12,
                                                                           ys[reg]+5+dg/12),
                                                                  YG=slice(ys[reg]-5-dg/12,
                                                                           ys[reg]+5+dg/12),
                                                                  XC=slice(xs[reg]-5-dg/12,
                                                                           xs[reg]+5+dg/12),
                                                                  XG=slice(xs[reg]-5-dg/12,
                                                                           xs[reg]+5+dg/12)
                                                                 )
                           ], dim='nmemb')

            # ds = ds.chunk({'nmemb':6})
    ds.coords['nmemb'] = ('nmemb',nmembs)
    if len(dsb.XG) > len(dsb.XC):
        dsb = dsb.isel(XG=slice(None,-1))
        ds = ds.isel(XG=slice(None,-1))
    
    grid = Grid(ds, periodic=False)
    # print(ds,grid)

    up = grid.interp((ds.UVEL - dsb.UVEL).where(ds.maskW!=0.),
                     'X',boundary='extend'
                    ).isel(Z=[14,18,24],YC=slice(dg,-dg),XC=slice(dg,-dg)).load()
    vp = grid.interp((ds.VVEL - dsb.VVEL).where(ds.maskS!=0.),
                     'Y',boundary='extend'
                    ).isel(Z=[14,18,24],YC=slice(dg,-dg),XC=slice(dg,-dg)).load()
    # up.isel(nmemb=0,Z=0).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
    # plt.show()
    
    xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
    xT = (xT - xT.isel(XC=0)).values.flatten()
    yT = (yT - yT.isel(YC=0)).values.flatten()
    
    dx = ds.dxC.min().values
    dy = ds.dyC.min().values
    N = up.isel(nmemb=0,Z=0).shape
    ss = xr.DataArray(np.linspace(2*np.maximum(dx,dy),10*xo,30)/xo, dims=['scale'], 
                      coords={'scale':np.linspace(2*dx,10*xo,30)/xo}
            )
    
    uterp = xr.DataArray(np.ones_like(up.isel(Z=-1)), dims=up.isel(Z=-1).dims,
                         coords={'nmemb':nmembs,
                                 # 'Z':up.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
            )
    vterp = xr.DataArray(np.ones_like(vp.isel(Z=-1)), dims=vp.isel(Z=-1).dims,
                         coords={'nmemb':nmembs,
                                 # 'Z':vp.Z,
                                 'YC':np.arange(0,N[-2]*dy,dy),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
            )
    Aterp = xr.DataArray(np.ones_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), 
                         dims=ds.rA.dims,
                         coords={'YC':np.arange(0,N[-2]*dx,dx),
                                 'XC':np.arange(0,N[-1]*dx,dx)}
            )
    #         xx, yy = np.meshgrid(np.arange(0,N[-1]*dx,dx), np.arange(0,N[-2]*dx,dx))
    xxx, yyy = np.mgrid[0:N[-1]*dx:dx, 0:N[-2]*dy:dy]
    for nn in range(len(nmembs)):
#         for iz in range(len(up.Z)):

#             uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (up*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 

#             vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
#                                                     (vp*ds.rA.isel(YC=slice(dg,-dg),
#                                                                    XC=slice(dg,-dg))
#                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
#                                                     (xxx, yyy) 
#                                                    ).T 
        uterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
                                           (up*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                           ).isel(nmemb=nn,Z=-1).values.flatten(),
                                           (xxx, yyy) 
                                          ).T 
        vterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
                                           (vp*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
                                           ).isel(nmemb=nn,Z=-1).values.flatten(),
                                           (xxx, yyy) 
                                          ).T 
            
    Aterp = griddata((xT, yT), (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
                     (xxx, yyy) 
                    ).T
    uterp = uterp / Aterp
    vterp = vterp / Aterp
    # uterp.isel(nmemb=0,Z=0).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
    # plt.show()
    #             print(nn)


    iso_psU = xwavelet.wvlt_power_spectrum(
                    uterp.chunk({'nmemb':1}), ss, dim=["YC", "XC"], xo=xo, ntheta=ntheta
    )
    iso_psV = xwavelet.wvlt_power_spectrum(
                    vterp.chunk({'nmemb':1}), ss, dim=["YC", "XC"], xo=xo, ntheta=ntheta
    )

    
    ps = .5*(iso_psU + iso_psV).mean('nmemb').sum('angle')
    dks = xr.DataArray(np.abs(np.diff(ps.scale**-1)).data, dims='scale',
                       coords={'scale':.5*(ps.scale[1:].data + ps.scale[:-1].data)}
                      ).interp(scale=ps.scale, kwargs={"fill_value": "extrapolate"})
    ax.plot((iso_psU.scale)**-1*1e3, ps/(ps*dks).sum(),
            lw=2, label=locs[reg]
           )

ax.plot((ps.scale)**-1*1e3, ((ps.scale/xo)**-1)**-3*1e2, 
        ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
ax.plot((ps.scale)**-1*1e3, ((ps.scale/xo)**-1)**-(13/3)*2e1, 
        ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
ax.set_xscale('log')
ax.set_yscale('log')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax.set_xlim([1e-3,1e-1])
ax2.set_xlim([1e-3,1e-1])
ax2.set_xticks([1e-3,1e-2,1e-1])
ax2.set_xticklabels([1e3,1e2,1e1])
ax.set_xlabel(r"[cpkm]", fontsize=13)
ax2.set_xlabel(r"[km]", fontsize=13)
ax.set_ylabel(r"[cpm$^{-1}$]", fontsize=13)
ax.legend(loc='lower left', fontsize=12)
plt.savefig(op.join('/tank/topog/tuchida/Wavelet-spectrum/Figs/NormalizedSnapKE-spec_Z1137.pdf'))
plt.show()
# Out:
# /tank/users/tuchida/miniconda3/envs/pyqg/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/pyqg/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/pyqg/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/pyqg/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/pyqg/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/pyqg/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/pyqg/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/pyqg/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/pyqg/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/pyqg/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/pyqg/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'netcdf4' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)
# /tank/users/tuchida/miniconda3/envs/pyqg/lib/python3.9/site-packages/xarray/backends/plugins.py:110: RuntimeWarning: 'scipy' fails while guessing
#   warnings.warn(f"{engine!r} fails while guessing", RuntimeWarning)

# %%
nmembs = np.arange(100,148)
xchunk = 100
ychunk = 100
dg = 1

yy = yystart
locs = ['A','B','C','D','E','F']

fig, ax = plt.subplots(figsize=(5,4))
fig.set_tight_layout(True)
ax2 = ax.twiny()
for reg in range(len(xs)):
    dsw = xr.open_zarr(
        '/tank/topog/tuchida/Wavelet-spectrum/isoDiags_KE_region%02d_1967-01-01.zarr'
                       % reg)
    iso_psUw = dsw.U
    iso_psVw = dsw.V
#     # dsb = open_mdsdataset(op.join(ddir,'ensm/run1967/ocn'), 
#     #                               grid_dir=gdir,
#     #                               prefix=['snap_diagOcn'], delta_t=2e2,
#     #                               iters=1419120, 
#     #                              ).isel(time=0).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
#     #                                                 YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
#     #                                                 XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
#     #                                                 XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
#     #                                                )
    
#     # ds0 = xr.open_dataset(op.join(savedir,'isoDiags_u_region%02d_1967-01-01.zarr' % reg))
#     # ds1 = xr.open_dataset(op.join(savedir,'isoDiags_v_region%02d_1967-01-01.zarr' % reg))
#     # ds4 = xr.open_dataset(op.join(savedir,'isoDiags-MtE_region%02d_1967-01-01.zarr' % reg))
#     # dks = xr.DataArray(np.abs(np.diff(ds1.scale**-1)).data, dims='scale',
#     #                    coords={'scale':.5*(ds1.scale[1:].data + ds1.scale[:-1].data)}
#     #                   ).interp(scale=ds1.scale, kwargs={"fill_value": "extrapolate"})
#     # Ak = (ds0.iso_uA + ds1.iso_vA
#     #       - (ds4.iso_uA + ds4.iso_vA))
#     # piw = ((Ak) * dks).cumsum('scale').mean('nmemb')
#     # piw = piw.where((piw.scale)**-1<1e-5).sum('scale',skipna=True).compute()
    
#     for nmemb in nmembs:
#         if nmemb == 100:
#             ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
#                                          % (nmemb)), 
#                                  grid_dir=gdir,
#                                  prefix=['snap_diagOcn'], delta_t=2e2,
#                                  iters=1419120, 
#                                 ).isel(time=0).sel(YC=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
#                                                    YG=slice(ys[reg]-5-dg/12,ys[reg]+5+dg/12),
#                                                    XC=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12),
#                                                    XG=slice(xs[reg]-5-dg/12,xs[reg]+5+dg/12)
#                                                   )
#         else:
#             ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
#                                                         % (nmemb)), 
#                                                 grid_dir=gdir,
#                                                 prefix=['snap_diagOcn'], delta_t=2e2,
#                                                 iters=1419120, 
#                                                ).isel(time=0).sel(YC=slice(ys[reg]-5-dg/12,
#                                                                            ys[reg]+5+dg/12),
#                                                                   YG=slice(ys[reg]-5-dg/12,
#                                                                            ys[reg]+5+dg/12),
#                                                                   XC=slice(xs[reg]-5-dg/12,
#                                                                            xs[reg]+5+dg/12),
#                                                                   XG=slice(xs[reg]-5-dg/12,
#                                                                            xs[reg]+5+dg/12)
#                                                                  )
#                            ], dim='nmemb')

#             # ds = ds.chunk({'nmemb':6})
#     ds.coords['nmemb'] = ('nmemb',nmembs)
#     if len(dsb.XG) > len(dsb.XC):
#         dsb = dsb.isel(XG=slice(None,-1))
#         ds = ds.isel(XG=slice(None,-1))
    
#     grid = Grid(ds, periodic=False)
#     # print(ds,grid)

#     up = grid.interp((ds.UVEL - dsb.UVEL).where(ds.maskW!=0.),
#                      'X',boundary='extend'
#                     ).isel(Z=[14,18,24],YC=slice(dg,-dg),XC=slice(dg,-dg)).load()
#     vp = grid.interp((ds.VVEL - dsb.VVEL).where(ds.maskS!=0.),
#                      'Y',boundary='extend'
#                     ).isel(Z=[14,18,24],YC=slice(dg,-dg),XC=slice(dg,-dg)).load()
#     # up.isel(nmemb=0,Z=0).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
#     # plt.show()
    
#     xT = grid.cumsum(ds.dxC,'X',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
#     yT = grid.cumsum(ds.dyC,'Y',boundary='extend').isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
#     xT = (xT - xT.isel(XC=0)).values.flatten()
#     yT = (yT - yT.isel(YC=0)).values.flatten()
    
#     dx = ds.dxC.min().values
#     dy = ds.dyC.min().values
#     N = up.isel(nmemb=0,Z=0).shape
#     ss = xr.DataArray(np.linspace(2*np.maximum(dx,dy),10*xo,30)/xo, dims=['scale'], 
#                       coords={'scale':np.linspace(2*dx,10*xo,30)/xo}
#             )
    
#     uterp = xr.DataArray(np.ones_like(up.isel(Z=1)), dims=up.isel(Z=-1).dims,
#                          coords={'nmemb':nmembs,
#                                  # 'Z':up.Z,
#                                  'YC':np.arange(0,N[-2]*dy,dy),
#                                  'XC':np.arange(0,N[-1]*dx,dx)}
#             )
#     vterp = xr.DataArray(np.ones_like(vp.isel(Z=1)), dims=vp.isel(Z=-1).dims,
#                          coords={'nmemb':nmembs,
#                                  # 'Z':vp.Z,
#                                  'YC':np.arange(0,N[-2]*dy,dy),
#                                  'XC':np.arange(0,N[-1]*dx,dx)}
#             )
#     Aterp = xr.DataArray(np.ones_like(ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))), 
#                          dims=ds.rA.dims,
#                          coords={'YC':np.arange(0,N[-2]*dx,dx),
#                                  'XC':np.arange(0,N[-1]*dx,dx)}
#             )
#     #         xx, yy = np.meshgrid(np.arange(0,N[-1]*dx,dx), np.arange(0,N[-2]*dx,dx))
#     xxx, yyy = np.mgrid[0:N[-1]*dx:dx, 0:N[-2]*dy:dy]
#     for nn in range(len(nmembs)):
# #         for iz in range(len(up.Z)):

# #             uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
# #                                                     (up*ds.rA.isel(YC=slice(dg,-dg),
# #                                                                    XC=slice(dg,-dg))
# #                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
# #                                                     (xxx, yyy) 
# #                                                    ).T 

# #             vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
# #                                                     (vp*ds.rA.isel(YC=slice(dg,-dg),
# #                                                                    XC=slice(dg,-dg))
# #                                                     ).isel(nmemb=nn,Z=iz).values.flatten(),
# #                                                     (xxx, yyy) 
# #                                                    ).T 
#         uterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
#                                            (up*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
#                                            ).isel(nmemb=nn,Z=1).values.flatten(),
#                                            (xxx, yyy) 
#                                           ).T 
#         vterp.isel(nmemb=nn)[:] = griddata((xT, yT), 
#                                            (vp*ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))
#                                            ).isel(nmemb=nn,Z=1).values.flatten(),
#                                            (xxx, yyy) 
#                                           ).T 
            
#     Aterp = griddata((xT, yT), (ds.rA.isel(YC=slice(dg,-dg),XC=slice(dg,-dg))).values.flatten(),
#                      (xxx, yyy) 
#                     ).T
#     uterp = uterp / Aterp
#     vterp = vterp / Aterp
#     # uterp.isel(nmemb=0,Z=0).plot(vmax=1, vmin=-1, cmap='RdBu_r', rasterized=True)
#     # plt.show()
#     #             print(nn)


#     iso_psU = xwavelet.wvlt_power_spectrum(
#                     uterp.chunk({'nmemb':1}), ss, dim=["YC", "XC"], xo=xo, ntheta=ntheta
#     )
#     iso_psV = xwavelet.wvlt_power_spectrum(
#                     vterp.chunk({'nmemb':1}), ss, dim=["YC", "XC"], xo=xo, ntheta=ntheta
#     )

    
    ps = .5*(iso_psUw + iso_psVw).mean('nmemb').sum('angle')
    dks = xr.DataArray(np.abs(np.diff(ps.scale**-1)).data, dims='scale',
                       coords={'scale':.5*(ps.scale[1:].data + ps.scale[:-1].data)}
                      ).interp(scale=ps.scale, kwargs={"fill_value": "extrapolate"})
    ax.plot((ps.scale)**-1*1e3, ps/(ps*dks).sum(),
            lw=2, label=locs[reg]
           )

ax.plot((ps.scale)**-1*1e3, ((ps.scale/xo)**-1)**-3*1e2, 
        ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
ax.plot((ps.scale)**-1*1e3, ((ps.scale/xo)**-1)**-(13/3)*2e1, 
        ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
ax.set_xscale('log')
ax.set_yscale('log')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax.set_xlim([1e-3,1e-1])
ax.set_ylim([None,1e6])
ax2.set_xlim([1e-3,1e-1])
ax2.set_xticks([1e-3,1e-2,1e-1])
ax2.set_xticklabels([1e3,1e2,1e1])
ax.grid(True)
ax.set_xlabel(r"[cpkm]", fontsize=13)
ax2.set_xlabel(r"[km]", fontsize=13)
ax.set_ylabel(r"[cpm$^{-1}$]", fontsize=13)
ax.legend(loc='lower left', fontsize=12)
plt.savefig(op.join('/tank/topog/tuchida/Wavelet-spectrum/Figs/NormalizedSnapKE-spec_Z452.pdf'))
plt.show()

# %% [markdown]
# # Fourier

# %%
nmembs = np.concatenate((np.arange(24),np.arange(36,60)))
xchunk = 100
ychunk = 100

yy = yystart

for reg in range(len(xs)-5):
    for year in years[yystart:]:
        if year == years[yystart]:
            mtimes = ntimes[yy,:dd+1]
        else:
            mtimes = ntimes[yy]
        for itime in mtimes:

            dsb = xr.open_zarr(op.join(tdgs,'5Dave/run%4d/Ensemble-mean/%2dmembers/15N-50N_%010d.zarr'
                                       % (year,len(nmembs),itime))
                              ).isel(time=0
                                    ).sel(YC=slice(ys[reg]-5,ys[reg]+5),
                                          YG=slice(ys[reg]-5,ys[reg]+5),
                                          XC=slice(xs[reg]-5,xs[reg]+5),
                                          XG=slice(xs[reg]-5,xs[reg]+5)
                                         ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1})

            for nmemb in nmembs:
                if nmemb == 0:
                    ds = open_mdsdataset(op.join(ddir,'qjamet/RUNS/ORAR/memb%02d/run%4d/ocn/' 
                                                 % (nmemb,year)), 
                                         grid_dir=op.join(ddir,'grid_chaO/gridMIT_update1/'),
                                         prefix=['diag_ocnTave'], delta_t=2e2,
                                         iters=itime, 
                                        ).sel(YC=slice(ys[reg]-5,ys[reg]+5),
                                              YG=slice(ys[reg]-5,ys[reg]+5),
                                              XC=slice(xs[reg]-5,xs[reg]+5),
                                              XG=slice(xs[reg]-5,xs[reg]+5)
                                             ).isel(time=0
                                                   ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1})
                else:
                    ds = xr.concat([ds, 
                                    open_mdsdataset(op.join(ddir,'qjamet/RUNS/ORAR/memb%02d/run%4d/ocn/' 
                                                            % (nmemb,year)), 
                                                    grid_dir=op.join(ddir,'grid_chaO/gridMIT_update1/'),
                                                    prefix=['diag_ocnTave'], delta_t=2e2,
                                                    iters=itime, 
                                                   ).sel(YC=slice(ys[reg]-5,ys[reg]+5),
                                                         YG=slice(ys[reg]-5,ys[reg]+5),
                                                         XC=slice(xs[reg]-5,xs[reg]+5),
                                                         XG=slice(xs[reg]-5,xs[reg]+5)
                                                        ).isel(time=0
                                                              ).chunk({'Z':1,'Zl':1,'Zu':1,'Zp1':1})
                                   ], dim='nmemb')

            # ds = ds.chunk({'nmemb':6})
            ds.coords['nmemb'] = ('nmemb',nmembs)

            grid = Grid(ds, periodic=[])

            up = grid.interp((ds.UVEL - dsb.UVEL).where(ds.maskW!=0.),
                             'X',boundary='extend').isel(Z=[14,24]).chunk({'YC':-1,'XC':-1}).interpolate_na(dim='XC'
                                                                   ).interpolate_na(dim='YC'
                                                                                   ).fillna(0.)
            vp = grid.interp((ds.VVEL - dsb.VVEL).where(ds.maskS!=0.),
                             'Y',boundary='extend').isel(Z=[14,24]).chunk({'YC':-1,'XC':-1}).interpolate_na(dim='YC'
                                                                   ).interpolate_na(dim='XC'
                                                                                   ).fillna(0.)

            xT = grid.cumsum(ds.dxC,'X',boundary='extend')
            yT = grid.cumsum(ds.dyC,'Y',boundary='extend')
            xT = (xT - xT.isel(XC=0)).values.flatten()
            yT = (yT - yT.isel(YC=0)).values.flatten()
            print(ds.dxC.mean(), ds.dyC.mean())
            dx = ds.dxC.min().values
            dy = ds.dyC.min().values
            N = up.isel(nmemb=0,Z=0).shape

            uterp = xr.DataArray(np.ones_like(up), dims=up.dims,
                                 coords={'nmemb':nmembs,'Z':up.Z,
                                         'YC':np.arange(0,N[-2]*dy,dy),
                                         'XC':np.arange(0,N[-1]*dx,dx)}
                                )
            vterp = xr.DataArray(np.ones_like(vp), dims=vp.dims,
                                 coords={'nmemb':nmembs,'Z':vp.Z,
                                         'YC':np.arange(0,N[-2]*dy,dy),
                                         'XC':np.arange(0,N[-1]*dx,dx)}
                                )
            mask = xr.DataArray(~ds.maskC.isel(Z=[14,24]).load(), 
                                dims=vp.isel(nmemb=0).dims,
                                coords={'Z':vp.Z,
                                        'YC':np.arange(0,N[-2]*dy,dy),
                                        'XC':np.arange(0,N[-1]*dx,dx)}
                               )

            xxx, yyy = np.mgrid[0:N[-1]*dx:dx, 0:N[-2]*dy:dy]
            for nn in range(len(nmembs)):
                for iz in range(len(up.Z)):

                    uterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
                                                            (up*ds.rA).isel(nmemb=nn,Z=iz).values.flatten(),
                                                            (xxx, yyy) 
                                                           ).T / (dx*dy)
                    vterp.isel(nmemb=nn,Z=iz)[:] = griddata((xT, yT), 
                                                            (vp*ds.rA).isel(nmemb=nn,Z=iz).values.flatten(),
                                                            (xxx, yyy) 
                                                           ).T / (dx*dy)


            psU = xrft.power_spectrum(
                    uterp.interpolate_na(dim='XC').interpolate_na(dim='YC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True
            )
            psV = xrft.power_spectrum(
                    vterp.interpolate_na(dim='YC').interpolate_na(dim='XC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True
            )

            iso_psU = xrft.isotropic_power_spectrum(
                    uterp.interpolate_na(dim='XC').interpolate_na(dim='YC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
            )
            iso_psV = xrft.isotropic_power_spectrum(
                    vterp.interpolate_na(dim='YC').interpolate_na(dim='XC').fillna(0.), 
                    dim=["YC", "XC"], window='hann', 
                    window_correction=True, true_amplitude=True, truncate=True
            )

            fig, ax = plt.subplots()
            fig.set_tight_layout(True)
            ax2 = ax.twinx()
            ax3 = ax.twiny()
            ax2.plot(psU.freq_XC[int(N[-1]/2)+1:]*1e3, 
                    .5*(psU + psV).isel(Z=0,freq_XC=slice(int(N[-1]/2)+1,None)).sel(freq_YC=0).mean(['nmemb']),
                    'r', lw=2, label=r"Zonal (Z=-228)")
            ax2.plot(psU.freq_YC[int(N[-2]/2)+1:]*1e3, 
                    .5*(psU + psV).isel(Z=0,freq_YC=slice(int(N[-2]/2)+1,None)).sel(freq_XC=0).mean(['nmemb']),
                    'c', lw=2, label=r"Meridional")
            ax.plot(iso_psU.freq_r[:]*1e3, .5*(iso_psU + iso_psV).isel(Z=0,freq_r=slice(None,None)).mean(['nmemb']),
                    'k', lw=2, label=r"Isotropic")
            ax2.plot(psU.freq_XC[int(N[-1]/2)+1:]*1e3, 
                    .5*(psU + psV).isel(Z=1,freq_XC=slice(int(N[-1]/2)+1,None)).sel(freq_YC=0).mean(['nmemb']),
                    'r:', lw=2)
            ax2.plot(psU.freq_YC[int(N[-2]/2)+1:]*1e3, 
                    .5*(psU + psV).isel(Z=1,freq_YC=slice(int(N[-2]/2)+1,None)).sel(freq_XC=0).mean(['nmemb']),
                    'c:', lw=2)
            ax.plot(iso_psU.freq_r[:]*1e3, .5*(iso_psU + iso_psV).isel(Z=1,freq_r=slice(None,None)).mean(['nmemb']),
                    'k:', lw=2, label=r"(Z=-1137)")
            ax.plot(iso_psU.freq_r*1e3, (iso_psU.freq_r*xo)**-3*2e-2, 
                     ls='--', c='grey', alpha=.8, label=r"$k^{-3}$")
            ax.plot(iso_psU.freq_r*1e3, (iso_psU.freq_r*xo)**-(13/3)*2e-2, 
                     ls='-.', c='grey', alpha=.8, label=r"$k^{-13/3}$")
            ax3.plot(iso_psU.freq_r*1e3, xr.ones_like(iso_psU.freq_r)*1e1, 
                     ls='--', c='grey', alpha=0)
            ax.set_xscale('log')
            ax.set_yscale('log')
            ax2.set_xscale('log')
            ax2.set_yscale('log')
            ax3.set_xscale('log')
            ax3.set_yscale('log')
            ax.set_xlim([1e-3,5e-2])
            ax3.set_xlim([1e-3,5e-2])
            ax3.set_xticks([1e-3,1e-2,5e-2])
            ax3.set_xticklabels([1e3,1e2,2e1])
            ax.set_xlabel(r"[cpkm]", fontsize=13)
            ax3.set_xlabel(r"[km]", fontsize=13)
            ax.set_ylabel(r"[(m$^2$ s$^{-2}$) / cpm]", fontsize=13)
            ax2.set_ylabel(r"[(m$^2$ s$^{-2}$) / cpm$^2$]", fontsize=13)
            if reg == 0:
                ax.legend(loc='lower left', fontsize=12)
                ax2.legend(loc='upper right', fontsize=12)
            plt.savefig(op.join('/tank/topog/tuchida/Wavelet-spectrum/Figs/KE-Fourierspec_Region%02d.pdf' % reg))
            plt.show()
# Out:
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1421280
#     time     timedelta64[ns] 3290 days <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1421280
#     time     timedelta64[ns] 3290 days
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1421280
#     time     timedelta64[ns] 3290 days <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1421280
#     time     timedelta64[ns] 3290 days
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1421280
#     time     timedelta64[ns] 3290 days <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1421280
#     time     timedelta64[ns] 3290 days
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1421280
#     time     timedelta64[ns] 3290 days <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1421280
#     time     timedelta64[ns] 3290 days
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1421280
#     time     timedelta64[ns] 3290 days <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1421280
#     time     timedelta64[ns] 3290 days
# <xarray.DataArray 'dxC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1421280
#     time     timedelta64[ns] 3290 days <xarray.DataArray 'dyC' ()>
# dask.array<mean_agg-aggregate, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     iter     int64 1421280
#     time     timedelta64[ns] 3290 days
